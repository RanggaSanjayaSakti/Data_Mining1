# %% [markdown]
# <a href="https://colab.research.google.com/github/RanggaSanjayaSakti/Data_Mining1/blob/main/RedWineQualityminiproject4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Understanding
#
# ## Business Understanding
#
# ### Business objective
# jadi tujuan bisnis dari dataset ini adalah untuk menganalisis dataset yang dapat membantu produsen red wine untuk memahami faktor-faktor apa saja yang berkontribusi terhadap kualitas red wine sehingga dapat membuat perubahan yang di perlukan untuk meningkatkan kualitas produk.
#
# ### Assess situation
# Situasi bisnis yang mendasari analisis ini adalah banyaknya para kompetitor yang bersaing dalam meningkatkan pasar dan dalam meningkatkan kualitas yang lebih baik untuk menarik minat konsumen.
#
# ### Tujuan data mining
# Tujuan data mining dari dataset red wine quality adalah untuk mengeksplorasi dan mengekstrak pola atau informasi berharga yang tersembunyi dalam data tersebut, dan juga untuk mengoptimasi produksi yaitu menggunakan data untuk mengoptimalkan parameter produksi guna meningkatkan kualitas dan mengurangi variasi dalam hasil red wine, lalu untuk mengidentifikasi tren pasar yaitu untuk menjelajahi data untuk mengidentifikasi tren pasar dan preferensi konsumen yang dapat memberikan keunggulan kompetitif.
#
# ### Rencana proyek
# Jadi tahapan tahapan yang dilakukan adalah
#
# 1. melakukan analisis eksploratif data yaitu melakukan EDA pada dataset red wine quality untuk memahami distribusi fitur, korelasi antar variabel, dll.
# 2. identifikasi faktor kualitas utama yaitu menggunakan teknik data mining untuk menentukan faktor-faktor kunci yang memengaruhi kualitas red wine.
# 3. segmentasi pasar yaitu mengidentifikasi segmen pasar yang memiliki preferensi kualitas tertentu.
# 4. optimasi produk yaitu menggunakan hasil analisis data untuk mengoptimalkan parameter-produksi guna mencapai konsistensi kualitas dan mengurangi variasi hasil anggur.
# 5. Strategi Pemasaran: Berdasarkan hasil analisis data, susun strategi pemasaran yang dapat menonjolkan keunggulan produk dan menarik segmen pasar yang diidentifikasi.

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Collect Initial Data

# %% [markdown]
# Dataset ini berasal dari website kaggle dan dataset ini terfokus pada varian anggur merah"vinho verde"portugal.lalu dataset ini hanya menyertakan variabel fisikokimia (input) dan sensori (output).untuk referensi dari dataset ini bisa ditemukan dengan merujuk kepenelitian asli yaitu(cortez et al.,2009).
# https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# # Describe Data

# %% [markdown]
# ## informasi dasar

# %%
jumlah_baris, jumlah_kolom = df.shape
print(f"Jumlah Baris: {jumlah_baris}")
print(f"Jumlah Kolom: {jumlah_kolom}")
# Out:
# Jumlah Baris: 1599
# Jumlah Kolom: 12

# %% [markdown]
# Dan untuk informasi baris dan kolom dari dataset ini adalah untuk barisnya yaitu berjumlah 1599 dan jumlah kolomnya yaitu 12

# %% [markdown]
# ## informasi lanjutan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# untuk informasi lengkap dari dataset ini adalah
# 1. nama kolom : fixed acidity
#    jumlah : 1599
#    tipe data : float64
# 2. nama kolom : volatile acidity
#    jumlah : 1599
#    tipe data : float64
# 3. nama kolom : citric acid
#    jumlah : 1599
#    tipe data : float64
# 4. nama kolom : residual sugar
#    jumlah : 1599
#    tipe data : float64
# 5. nama kolom : chlorides
#    jumlah : 1599
#    tipe data : float64
# 6. nama kolom : free sulfur dioxide
#    jumlah : 1599
#    tipe data : float64
# 7. nama kolom : total sulfur dioxide
#    jumlah : 1599
#    tipe data : float64
# 8. nama kolom : density
#    jumlah : 1599
#    tipe data : float64
# 9. nama kolom : pH
#    jumlah : 1599
#    tipe data : float64
# 10. nama kolom : sulphates
#    jumlah : 1599
#    tipe data : float64
# 11. nama kolom : alcohol
#    jumlah : 1599
#    tipe data : float64
# 12. nama kolom : quality
#    jumlah : 1599
#    tipe data : int64

# %% [markdown]
# ## informasi statistik deskriptif

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# Berikut adalah data statistik deskriptif untuk setiap kolom pada dataset red wine quality:
#
# Fixed Acidity :
# - Jumlah: 1599
# - Rata-rata: 8.319637
# - Standar Deviasi: 1.741096
# - Minimum: 4.6
# - 25%: 7.1
# - 50%: 7.9
# - 75%: 9.2
# - Maksimum: 15.9
#
# Volatile Acidity :
# - Jumlah: 1599
# - Rata-rata: 0.527821
# - Standar Deviasi: 0.179060
# - Minimum: 0.12
# - 25%: 0.39
# - 50%: 0.52
# - 75%: 0.64
# - Maksimum: 1.58
#
# Citric Acid :
# - Jumlah: 1599
# - Rata-rata: 0.270976
# - Standar Deviasi: 0.194801
# - Minimum: 0.0
# - 25%: 0.09
# - 50%: 0.26
# - 75%: 0.42
# - Maksimum: 1.0
#
# Residual Sugar :
# - Jumlah: 1599
# - Rata-rata: 2.538806
# - Standar Deviasi: 1.409928
# - Minimum: 0.9
# - 25%: 1.9
# - 50%: 2.2
# - 75%: 2.6
# - Maksimum: 15.5
#
# Chlorides:
# - Jumlah: 1599
# - Rata-rata: 0.087467
# - Standar Deviasi: 0.047065
# - Minimum: 0.012
# - 25%: 0.07
# - 50%: 0.079
# - 75%: 0.09
# - Maksimum: 0.611
#
# Free Sulfur Dioxide :
# - Jumlah: 1599
# - Rata-rata: 15.874922
# - Standar Deviasi: 10.460157
# - Minimum: 1.0
# - 25%: 7.0
# - 50%: 14.0
# - 75%: 21.0
# - Maksimum: 72.0
#
# Total Sulfur Dioxide :
# - Jumlah: 1599
# - Rata-rata: 46.467792
# - Standar Deviasi: 32.895324
# - Minimum: 6.0
# - 25%: 22.0
# - 50%: 38.0
# - 75%: 62.0
# - Maksimum: 289.0
#
# Density :
# - Jumlah: 1599
# - Rata-rata: 0.996747
# - Standar Deviasi: 0.001887
# - Minimum: 0.99007
# - 25%: 0.9956
# - 50%: 0.99675
# - 75%: 0.997835
# - Maksimum: 1.00369
#
# pH:
# - Jumlah: 1599
# - Rata-rata: 3.311113
# - Standar Deviasi: 0.154386
# - Minimum: 2.74
# - 25%: 3.21
# - 50%: 3.31
# - 75%: 3.4
# - Maksimum: 4.01
#
# Sulphates :
# - Jumlah: 1599
# - Rata-rata: 0.658149
# - Standar Deviasi: 0.169507
# - Minimum: 0.33
# - 25%: 0.55
# - 50%: 0.62
# - 75%: 0.73
# - Maksimum: 2.0
#
# Alcohol :
# - Jumlah: 1599
# - Rata-rata: 10.422983
# - Standar Deviasi: 1.065668
# - Minimum: 8.4
# - 25%: 9.5
# - 50%: 10.2
# - 75%: 11.1
# - Maksimum: 14.9
#
# Quality :
# - Jumlah: 1599
# - Rata-rata: 5.636023
# - Standar Deviasi: 0.807569
# - Minimum: 3.0
# - 25%: 5.0
# - 50%: 6.0
# - 75%: 6.0
# - Maksimum: 8.0

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='quality', data=df  , palette='viridis')
plt.title('Distribusi Kualitas Anggur')
plt.xlabel('Kualitas')
plt.ylabel('Jumlah')
plt.show()
# Out:
# <ipython-input-222-fd3cf7b77f16>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# visualisasi diatas menunjukkan distribusi jumlah observasi untuk setiap tingkat kualitas anggur yang ada didalam dataset ini dan dapat dilihat bahwa kualitas anggur banyak yang berada pada nilai 5 dan 6, dapat diasumsi kan bahwa sebagian besar anggur dalam dataset ini memiliki kualitas yang cukup baik, dan sementara untuk kulaitas yang lebih rendah sangat jarang ditemui.

# %% [markdown]
# # Verify Data Quality

# %% [markdown]
# ## Missing Values

# %%
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Hasil yang ditampilkan menunjukkan bahwa tidak ada nilai kosong (missing values) dalam dataset untuk setiap kolom. Setiap kolom memiliki jumlah nilai kosong yang sama dengan 0. Dengan kata lain, dataset ini lengkap, dan tidak ditemukan nilai yang hilang dalam kolom-kolom yang disebutkan.

# %% [markdown]
# ## Outliers Values

# %%
def detect_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1

    outliers = (column < (Q1 - 1.5 * IQR)) | (column > (Q3 + 1.5 * IQR))

    percentage_outliers = outliers.sum() / len(column) * 100

    return outliers, percentage_outliers

for column in df.columns:
    outliers, percentage_outliers = detect_outliers(df[column])

    print(f"Kolom '{column}':")
    print(f"  - Jumlah outliers: {outliers.sum()}")
    print(f"  - Persentase kehadiran outliers: {percentage_outliers:.2f}%")
    print()
# Out:
# Kolom 'fixed acidity':
#   - Jumlah outliers: 49
#   - Persentase kehadiran outliers: 3.06%
#
# Kolom 'volatile acidity':
#   - Jumlah outliers: 19
#   - Persentase kehadiran outliers: 1.19%
#
# Kolom 'citric acid':
#   - Jumlah outliers: 1
#   - Persentase kehadiran outliers: 0.06%
#
# Kolom 'residual sugar':
#   - Jumlah outliers: 155
#   - Persentase kehadiran outliers: 9.69%
#
# Kolom 'chlorides':
#   - Jumlah outliers: 112
#   - Persentase kehadiran outliers: 7.00%
#
# Kolom 'free sulfur dioxide':
#   - Jumlah outliers: 30
#   - Persentase kehadiran outliers: 1.88%
#
# Kolom 'total sulfur dioxide':
#   - Jumlah outliers: 55
#   - Persentase kehadiran outliers: 3.44%
#
# Kolom 'density':
#   - Jumlah outliers: 45
#   - Persentase kehadiran outliers: 2.81%
#
# Kolom 'pH':
#   - Jumlah outliers: 35
#   - Persentase kehadiran outliers: 2.19%
#
# Kolom 'sulphates':
#   - Jumlah outliers: 59
#   - Persentase kehadiran outliers: 3.69%
#
# Kolom 'alcohol':
#   - Jumlah outliers: 13
# ...

# %% [markdown]
# 1. Kolom 'fixed acidity':
# - Jumlah outliers: 49
# - Persentase kehadiran outliers: 3.06%
# - Terdapat 49 nilai yang dianggap sebagai outliers dalam kolom 'fixed - acidity'. Persentase ini mencerminkan seberapa besar persentase data yang dianggap sebagai nilai yang ekstrem.
#
# 2.Kolom 'volatile acidity':
# - Jumlah outliers: 19
# - Persentase kehadiran outliers: 1.19%
# - Ditemukan 19 nilai yang dianggap sebagai outliers dalam kolom 'volatile acidity'. Persentase kehadiran outliers relatif rendah.
#
# 3. Kolom 'citric acid':
# - Jumlah outliers: 1
# - Persentase kehadiran outliers: 0.06%
# - Hanya ada 1 nilai yang dianggap sebagai outlier dalam kolom 'citric acid'. Persentase kehadiran outliers sangat rendah.
#
# 4. Kolom 'residual sugar':
# - Jumlah outliers: 155
# - Persentase kehadiran outliers: 9.69%
# - Terdapat 155 nilai yang dianggap sebagai outliers dalam kolom 'residual sugar'. Persentase kehadiran outliers tinggi.
#
# 5. Kolom 'chlorides':
# - Jumlah outliers: 112
# - Persentase kehadiran outliers: 7.00%
# - Ditemukan 112 nilai yang dianggap sebagai outliers dalam kolom 'chlorides'. Persentase kehadiran outliers cukup signifikan.

# %% [markdown]
# ## Duplicated Values

# %%
duplicate_values =(df.duplicated())

print("Apakah Ada Nilai Duplikat pada Tiap Kolom:")
print(duplicate_values)
# Out:
# Apakah Ada Nilai Duplikat pada Tiap Kolom:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %% [markdown]
# untuk hasil dari duplikat dataset yang ada di atas dapat disimpulkan bahwa banyak data yang tidak duplikat sehingga tidak berpengaruh terhadap statistik deskriptif yang berarti bisa menjadi bias dan tidak mencerminkan variasi sebenarnya didalam dataset.

# %%
(df[df.duplicated()])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Missing Values

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# fixed acidity           0.0
# volatile acidity        0.0
# citric acid             0.0
# residual sugar          0.0
# chlorides               0.0
# free sulfur dioxide     0.0
# total sulfur dioxide    0.0
# density                 0.0
# pH                      0.0
# sulphates               0.0
# alcohol                 0.0
# quality                 0.0
# dtype: float64

# %% [markdown]
# pada data diatas adalah menunjukkan bahwa tidak ada data yang hilang.

# %% [markdown]
# ## Hapus missing values

# %% [markdown]
# pada dataset ini menunjukkan bahwa tidak ada missing values yang harus di hapus

# %% [markdown]
# # imputasi missing values

# %% [markdown]
# pada dataset ini tidak diperlukan imputasi

# %% [markdown]
# # pengecekan ulang

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#                       Null Ratio %
# fixed acidity                  0.0
# volatile acidity               0.0
# citric acid                    0.0
# residual sugar                 0.0
# chlorides                      0.0
# free sulfur dioxide            0.0
# total sulfur dioxide           0.0
# density                        0.0
# pH                             0.0
# sulphates                      0.0
# alcohol                        0.0
# quality                        0.0

# %% [markdown]
# # Penanganan Duplicated Values

# %% [markdown]
# ## Pengecekkan Nilai Duplikat

# %%
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %% [markdown]
# ## hapus nilai duplikat

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# pada data diatas merupakan data yang sudah dihapus duplikatnya.

# %% [markdown]
# # Penanganan Outliers

# %% [markdown]
# ## pengecekan outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                 Persentase Outliers
# fixed acidity                    3.016924
# volatile acidity                 1.398087
# citric acid                      0.073584
# residual sugar                   9.271523
# chlorides                        6.401766
# free sulfur dioxide              1.913171
# total sulfur dioxide             3.311258
# density                          2.575423
# pH                               2.060338
# sulphates                        4.047093
# alcohol                          0.883002
# quality                          1.986755

# %% [markdown]
# 1.  **Fixed Acidity (3.02%):**
#
#     *   Persentase outliers untuk fixed acidity adalah sekitar 3.02%. Ini mungkin menunjukkan bahwa ada beberapa sampel anggur dengan tingkat keasaman tetap yang signifikan lebih tinggi atau lebih rendah dari sebagian besar sampel.
# 2.  **Volatile Acidity (1.40%):**
#
#     *   Persentase outliers untuk volatile acidity adalah sekitar 1.40%. Hal ini bisa menunjukkan bahwa sebagian kecil sampel anggur memiliki tingkat asam yang sangat tinggi atau rendah.
# 3.  **Citric Acid (0.07%):**
#
#     *   Persentase outliers untuk citric acid sangat rendah, sekitar 0.07%. Ini menunjukkan bahwa sebagian besar sampel anggur memiliki kandungan asam sitrat yang seragam.
# 4.  **Residual Sugar (9.27%):**
#
#     *   Persentase outliers untuk residual sugar tinggi, mencapai 9.27%. Ini mungkin menunjukkan adanya beberapa sampel anggur dengan tingkat gula yang jauh lebih tinggi dari yang umumnya diharapkan.
# 5.  **Chlorides (6.40%):**
#
#     *   Persentase outliers untuk klorida adalah sekitar 6.40%. Ini bisa menandakan adanya variasi besar dalam kandungan klorida di antara sampel anggur.
# 6.  **Free Sulfur Dioxide (1.91%):**
#
#     *   Persentase outliers untuk free sulfur dioxide sekitar 1.91%. Ini mungkin menunjukkan adanya beberapa sampel dengan tingkat sulfur dioksida bebas yang signifikan.
# 7.  **Total Sulfur Dioxide (3.31%):**
#
#     *   Persentase outliers untuk total sulfur dioxide adalah sekitar 3.31%. Hal ini menunjukkan variasi dalam jumlah total sulfur dioksida di antara sampel anggur.
# 8.  **Density (2.58%):**
#
#     *   Persentase outliers untuk densitas adalah sekitar 2.58%. Ini bisa menandakan adanya variasi dalam kepadatan anggur.
# 9.  **pH (2.06%):**
#
#     *   Persentase outliers untuk pH adalah sekitar 2.06%. Ini menunjukkan variasi dalam tingkat keasaman relatif anggur.
# 10.  **Sulphates (4.05%):**
#
#
# *   Persentase outliers untuk sulphates sekitar 4.05%. Ini bisa menunjukkan variasi dalam kandungan sulfat di antara sampel anggur.
#
# 11.  **Alcohol (0.88%):**
#
# *   Persentase outliers untuk kadar alkohol relatif rendah, sekitar 0.88%. Ini mungkin menunjukkan bahwa sebagian besar sampel anggur memiliki tingkat alkohol yang seragam.
#
# 12.  **Quality (1.99%):**
#
# *   Persentase outliers untuk kualitas anggur sekitar 1.99%. Ini menunjukkan bahwa sebagian kecil dari sampel anggur memiliki nilai kualitas yang signifikan lebih tinggi atau lebih rendah dari sebagian besar sampel.

# %%
boxplot = df.drop('alcohol', axis=1).boxplot(grid=False, rot=45,  figsize=(8,6))

# %% [markdown]
# ## hapus outliers

# %%
Q1 = df['fixed acidity'].quantile(0.25)
Q3 = df['fixed acidity'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['fixed acidity'] >= lower_bound) & (df['fixed acidity'] <= upper_bound)]

# %%
Q1 = df['volatile acidity'].quantile(0.25)
Q3 = df['volatile acidity'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['volatile acidity'] >= lower_bound) & (df['volatile acidity'] <= upper_bound)]

# %%
Q1 = df['citric acid'].quantile(0.25)
Q3 = df['citric acid'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['citric acid'] >= lower_bound) & (df['citric acid'] <= upper_bound)]

# %%
Q1 = df['residual sugar'].quantile(0.25)
Q3 = df['residual sugar'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['residual sugar'] >= lower_bound) & (df['residual sugar'] <= upper_bound)]

# %%
Q1 = df['chlorides'].quantile(0.25)
Q3 = df['chlorides'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['chlorides'] >= lower_bound) & (df['chlorides'] <= upper_bound)]

# %%
Q1 = df['free sulfur dioxide'].quantile(0.25)
Q3 = df['free sulfur dioxide'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['free sulfur dioxide'] >= lower_bound) & (df['free sulfur dioxide'] <= upper_bound)]

# %%
Q1 = df['total sulfur dioxide'].quantile(0.25)
Q3 = df['total sulfur dioxide'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['total sulfur dioxide'] >= lower_bound) & (df['total sulfur dioxide'] <= upper_bound)]

# %%
Q1 = df['density'].quantile(0.25)
Q3 = df['density'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['density'] >= lower_bound) & (df['density'] <= upper_bound)]

# %%
Q1 = df['pH'].quantile(0.25)
Q3 = df['pH'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['pH'] >= lower_bound) & (df['pH'] <= upper_bound)]

# %%
Q1 = df['sulphates'].quantile(0.25)
Q3 = df['sulphates'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['sulphates'] >= lower_bound) & (df['sulphates'] <= upper_bound)]

# %%
Q1 = df['alcohol'].quantile(0.25)
Q3 = df['alcohol'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['alcohol'] >= lower_bound) & (df['alcohol'] <= upper_bound)]

# %%
Q1 = df['quality'].quantile(0.25)
Q3 = df['quality'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['quality'] >= lower_bound) & (df['quality'] <= upper_bound)]

# %% [markdown]
# diatas merupakan proses buat menghilangkan outliers pada dataset ini

# %% [markdown]
# # Pengecekkan Ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom                 Persentase Outliers
# fixed acidity                    1.950719
# volatile acidity                 0.205339
# citric acid                      0.000000
# residual sugar                   0.924025
# chlorides                        1.745380
# free sulfur dioxide              0.718686
# total sulfur dioxide             2.156057
# density                          0.308008
# pH                               0.205339
# sulphates                        0.616016
# alcohol                          0.308008
# quality                          0.000000

# %% [markdown]
# *   **Fixed Acidity (1.95%):**
#
#     *   Persentase outliers untuk fixed acidity adalah sekitar 1.95%. Ini menunjukkan bahwa sebagian kecil sampel anggur memiliki tingkat keasaman tetap yang cukup berbeda dari sebagian besar sampel.
# *   **Volatile Acidity (0.21%):**
#
#     *   Persentase outliers untuk volatile acidity sangat rendah, sekitar 0.21%. Ini menunjukkan bahwa sebagian besar sampel anggur memiliki tingkat asam yang relatif seragam.
# *   **Citric Acid (0.00%):**
#
#     *   Persentase outliers untuk citric acid adalah nol, artinya semua nilai dalam kolom ini memiliki nilai yang tidak tergolong sebagai outliers. Ini menunjukkan bahwa kandungan asam sitrat dalam sampel anggur relatif seragam.
# *   **Residual Sugar (0.92%):**
#
#     *   Persentase outliers untuk residual sugar adalah sekitar 0.92%. Ini menunjukkan bahwa sebagian kecil sampel anggur memiliki tingkat gula yang berbeda secara signifikan dari sebagian besar sampel.
# *   **Chlorides (1.75%):**
#
#     *   Persentase outliers untuk klorida adalah sekitar 1.75%. Hal ini menunjukkan variasi dalam kandungan klorida di antara sampel anggur, meskipun tidak signifikan.
# *   **Free Sulfur Dioxide (0.72%):**
#
#     *   Persentase outliers untuk free sulfur dioxide sekitar 0.72%. Ini menunjukkan adanya beberapa sampel dengan tingkat sulfur dioksida bebas yang sedikit berbeda dari sebagian besar sampel.
# *   **Total Sulfur Dioxide (2.16%):**
#
#     *   Persentase outliers untuk total sulfur dioxide adalah sekitar 2.16%. Hal ini menunjukkan variasi dalam jumlah total sulfur dioksida di antara sampel anggur.
# *   **Density (0.31%):**
#
#     *   Persentase outliers untuk densitas adalah sekitar 0.31%. Ini menunjukkan variasi dalam kepadatan anggur, meskipun tidak signifikan.
# *   **pH (0.21%):**
#
#     *   Persentase outliers untuk pH adalah sekitar 0.21%. Ini menunjukkan variasi dalam tingkat keasaman relatif anggur, tetapi tidak signifikan.
# *   **Sulphates (0.62%):**
#
#     *   Persentase outliers untuk sulphates sekitar 0.62%. Ini menunjukkan variasi dalam kandungan sulfat di antara sampel anggur, meskipun tidak signifikan.
# *   **Alcohol (0.31%):**
#
#     *   Persentase outliers untuk kadar alkohol relatif rendah, sekitar 0.31%. Ini menunjukkan bahwa sebagian besar sampel anggur memiliki tingkat alkohol yang seragam.
# *   **Quality (0.00%):**
#
#     *   Persentase outliers untuk kualitas anggur adalah nol, artinya semua nilai dalam kolom ini tidak tergolong sebagai outliers. Ini menunjukkan bahwa nilai kualitas dalam sampel anggur relatif seragam.

# %%
boxplot = df.drop('alcohol', axis=1).boxplot(grid=False, rot=45,  figsize=(8,6))

# %% [markdown]
# # Construct Data

# %% [markdown]
# ## Melakukan Rekayasa Fitur (Feature Engineering)
#
# Pada kolom 'alcohol_type' dan 'alcohol_category' yang telah ditambahkan sebelumnya, mungkin telah dilakukan kategorisasi berdasarkan kandungan alkohol untuk mempermudah analisis dan interpretasi.

# %%
min_alcohol = df['alcohol'].min()
max_alcohol = df['alcohol'].max()

# Membuat kolom 'alcohol_type' berdasarkan kategori
df['alcohol_category'] = pd.cut(df['alcohol'], bins=[min_alcohol -1, 10, 15, float('inf')],
                                 labels=['low', 'moderate', 'high'])

# %% [markdown]
# ## Pengecekan hasil

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality alcohol_category
# 0      9.4        5              low
# ...

# %% [markdown]
# hasil data diatas merupakan hasil data alcohol yang sudah dikategorikan

# %% [markdown]
# # Data Reduction

# %% [markdown]
# ## Mengurangi Fitur - Fitur Yang Kurang Relevan

# %%
df_corr = df.corr(numeric_only=True)
px.imshow(df_corr)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# dataset ini tidak ada yang dihapus karena semua datanya relevan

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ## mapping

# %%
df['alcohol_category'] = df['alcohol_category'].map({'low':1,'medium':2,'high':3})

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality  alcohol_category
# 0      9.4        5               1.0
# ...

# %% [markdown]
# 1.  **Baris Pertama:**
#
#     *   **Fixed Acidity:** 7.4
#     *   **Volatile Acidity:** 0.70
#     *   **Citric Acid:** 0.00
#     *   **Residual Sugar:** 1.9
#     *   **Chlorides:** 0.076
#     *   **Free Sulfur Dioxide:** 11.0
#     *   **Total Sulfur Dioxide:** 34.0
#     *   **Density:** 0.9978
#     *   **pH:** 3.51
#     *   **Sulphates:** 0.56
#     *   **Alcohol:** 9.4
#     *   **Quality:** 5
#     *   **Alcohol Type:** 'low'
#     *   **Alcohol Category:** 1.0
# 2.  **Baris Kedua:**
#
#     *   **Fixed Acidity:** 7.8
#     *   **Volatile Acidity:** 0.88
#     *   **Citric Acid:** 0.00
#     *   **Residual Sugar:** 2.6
#     *   **Chlorides:** 0.098
#     *   **Free Sulfur Dioxide:** 25.0
#     *   **Total Sulfur Dioxide:** 67.0
#     *   **Density:** 0.9968
#     *   **pH:** 3.20
#     *   **Sulphates:** 0.68
#     *   **Alcohol:** 9.8
#     *   **Quality:** 5
#     *   **Alcohol Type:** 'low'
#     *   **Alcohol Category:** 1.0
# 3.  **Baris Ketiga:**
#
#     *   **Fixed Acidity:** 7.8
#     *   **Volatile Acidity:** 0.76
#     *   **Citric Acid:** 0.04
#     *   **Residual Sugar:** 2.3
#     *   **Chlorides:** 0.092
#     *   **Free Sulfur Dioxide:** 15.0
#     *   **Total Sulfur Dioxide:** 54.0
#     *   **Density:** 0.9970
#     *   **pH:** 3.26
#     *   **Sulphates:** 0.65
#     *   **Alcohol:** 9.8
#     *   **Quality:** 5
#     *   **Alcohol Type:** 'low'
#     *   **Alcohol Category:** 1.0
# 4.  **Baris Keempat:**
#
#     *   **Fixed Acidity:** 11.2
#     *   **Volatile Acidity:** 0.28
#     *   **Citric Acid:** 0.56
#     *   **Residual Sugar:** 1.9
#     *   **Chlorides:** 0.075
#     *   **Free Sulfur Dioxide:** 17.0
#     *   **Total Sulfur Dioxide:** 60.0
#     *   **Density:** 0.9980
#     *   **pH:** 3.16
#     *   **Sulphates:** 0.58
#     *   **Alcohol:** 9.8
#     *   **Quality:** 6
#     *   **Alcohol Type:** 'low'
#     *   **Alcohol Category:** 1.0
# 5.  **Baris Kelima:**
#
#     *   **Fixed Acidity:** 7.4
#     *   **Volatile Acidity:** 0.66
#     *   **Citric Acid:** 0.00
#     *   **Residual Sugar:** 1.8
#     *   **Chlorides:** 0.075
#     *   **Free Sulfur Dioxide:** 13.0
#     *   **Total Sulfur Dioxide:** 40.0
#     *   **Density:** 0.9978
#     *   **pH:** 3.51
#     *   **Sulphates:** 0.56
#     *   **Alcohol:** 9.4
#     *   **Quality:** 5
#     *   **Alcohol Type:** 'low'
#     *   **Alcohol Category:** Data tidak lengkap (tidak ada nilai).
#
# Mapping ini memberikan informasi tentang nilai setiap atribut pada setiap baris dalam dataset. Dengan melihat mapping ini, dapat lebih mudah untuk memahami dan menganalisis data anggur yang diberikan.

# %%
df.to_csv('DataCleaned.csv', index=False)

# %% [markdown]
# ## Library untuk splitting data

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Library untuk normalisasi data

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Library Untuk Build Model

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import accuracy_score

# %% [markdown]
# # inisiasi

# %%
df=pd.read_csv('https://raw.githubusercontent.com/RanggaSanjayaSakti/Data_Mining1/main/DataCleaned%20(2).csv')

# %% [markdown]
# # Select Modelling Techniques

# %% [markdown]
# ## Model Prediktif

# %% [markdown]
# pada dataset ini saya menggunakan Metode prediksi bertujuan untuk memprediksi nilai variabel target berdasarkan variabel input yang diberikan. Jadi, untuk menganalisis dataset kualitas anggur merah, lebih tepat menggunakan metode prediksi untuk menghasilkan model yang dapat memprediksi kualitas anggur berdasarkan atribut-atribut yang ada.

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# # Pre Processing

# %% [markdown]
# ## Split data

# %%
x = df.drop('alcohol', axis=1)
y = df['alcohol']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# jadi pada dataset saya ini karena baris nya kurang dari 1000 maka saya menggunakan rasio 7:3 dan test_size nya menggunakan 0.3 dan split data berguna untuk menghindari overfitting dan mengevaluasi kinerja model secara obyektif

# %% [markdown]
# ## Normalisasi Data

# %%
scaler = MinMaxScaler()

x_train_norm = scaler.fit_transform(x_train)

x_test_norm = scaler.transform(x_test)

# %% [markdown]
# jadi pada syntax ini ketika dijalankan kita mendapatkan dua set data yang telah dinormalisasi: x_train_norm (data pelatihan yang telah dinormalisasi) dan x_test_norm (data pengujian yang telah dinormalisasi). Data ini siap digunakan untuk melatih dan menguji model machine learning. Dengan melakukan penskalaan fitur, kita dapat meningkatkan kinerja model, terutama untuk algoritma-algoritma yang sensitif terhadap skala fitur, seperti algoritma jarak-berbasis (distance-based algorithms) dan algoritma gradien (gradient-based algorithms).

# %% [markdown]
# # Build and Train model

# %% [markdown]
# ## Gaussian Naive Bayes

# %%
# Mengubah nilai-nilai menjadi kategori berdasarkan batas nilai
bins = [0, 10, np.inf]  # 0-10 adalah "rendah", >10 adalah "tinggi"
labels = ['rendah', 'tinggi']
y_train_categorical = pd.cut(y_train, bins=bins, labels=labels)

# Sekarang Anda bisa menggunakan y_train_categorical sebagai label untuk DecisionTreeClassifier
gnb.fit(x_train_norm, y_train_categorical)
# Out:
# GaussianNB()

# %% [markdown]
# Setelah menjalankan syntax ini, model Gaussian Naive Bayes (GNB) akan dilatih menggunakan data pelatihan yang telah dinormalisasi (x_train_norm) dan label-label kategori yang baru saja dibuat (y_train_categorical). Model ini akan siap untuk digunakan untuk melakukan prediksi terhadap data baru. Dengan menggunakan kategori sebagai label, kita dapat menggunakan algoritma klasifikasi yang membutuhkan label dalam bentuk diskrit untuk melatih model.

# %% [markdown]
# # K-Nearest Neighbor

# %%
# Mengubah nilai-nilai menjadi kategori berdasarkan batas nilai
bins = [0, 10, np.inf]  # 0-10 adalah "rendah", >10 adalah "tinggi"
labels = ['rendah', 'tinggi']
y_train_categorical = pd.cut(y_train, bins=bins, labels=labels)

# Sekarang Anda bisa menggunakan y_train_categorical sebagai label untuk DecisionTreeClassifier
knn.fit(x_train_norm, y_train_categorical)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Setelah menjalankan syntax ini, model K-Nearest Neighbors (KNN) akan dilatih menggunakan data pelatihan yang telah dinormalisasi (x_train_norm) dan label-label kategori yang baru saja dibuat (y_train_categorical). Model ini akan siap untuk digunakan untuk melakukan prediksi terhadap data baru. Dengan menggunakan kategori sebagai label, kita dapat menggunakan algoritma klasifikasi yang membutuhkan label dalam bentuk diskrit untuk melatih model.

# %% [markdown]
# # Decision Tree

# %%
# Mengubah nilai-nilai menjadi kategori berdasarkan batas nilai
bins = [0, 10, np.inf]  # 0-10 adalah "rendah", >10 adalah "tinggi"
labels = ['rendah', 'tinggi']
y_train_categorical = pd.cut(y_train, bins=bins, labels=labels)

# Sekarang Anda bisa menggunakan y_train_categorical sebagai label untuk DecisionTreeClassifier
dtc.fit(x_train_norm, y_train_categorical)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Setelah menjalankan syntax ini, model Decision Tree Classifier (DTC) akan dilatih menggunakan data pelatihan yang telah dinormalisasi (x_train_norm) dan label-label kategori yang baru saja dibuat (y_train_categorical). Model ini akan siap untuk digunakan untuk melakukan prediksi terhadap data baru. Dengan menggunakan kategori sebagai label, kita dapat menggunakan algoritma klasifikasi yang membutuhkan label dalam bentuk diskrit untuk melatih model.

# %% [markdown]
# # Begins and Compare Predict

# %%
gnb_pred = gnb.predict(x_test_norm)
knn_pred = knn.predict(x_test_norm)
dtc_pred = dtc.predict(x_test_norm)

# %% [markdown]
# Setelah menjalankan syntax ini, kita akan mendapatkan tiga set prediksi: gnb_pred, knn_pred, dan dtc_pred. Setiap set prediksi ini akan berisi prediksi label dari data pengujian yang dilakukan oleh masing-masing model yang telah dilatih sebelumnya. Prediksi-prediksi ini dapat digunakan untuk mengevaluasi kinerja model dan melakukan analisis lebih lanjut terhadap data.

# %%
x_test = pd.DataFrame(x_test).reset_index(drop=True)

y_test = pd.DataFrame(y_test).reset_index(drop=True)

# Membuat DataFrame hasil prediksi untuk Gaussian Naive Bayes
gnb_col = pd.DataFrame(gnb_pred, columns=["gnb_prediction"])

# Membuat DataFrame hasil prediksi untuk KNeighborsClassifier
knn_col = pd.DataFrame(knn_pred, columns=["knn_prediction"])

# Membuat DataFrame hasil prediksi untuk DecisionTreeClassifier
dtc_col = pd.DataFrame(dtc_pred, columns=["dtc_prediction"])

combined_data = pd.concat([x_test, y_test, gnb_col, knn_col, dtc_col], axis=1)

# %% [markdown]
# Setelah menjalankan syntax ini, kita akan mendapatkan DataFrame combined_data yang berisi data pengujian, label sebenarnya (y_test), serta hasil prediksi dari tiga model yang berbeda. DataFrame ini dapat digunakan untuk melakukan analisis lebih lanjut, mengevaluasi kinerja model, dan membandingkan hasil prediksi antar model.

# %%
combined_data.sample(10)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 203            7.2             0.620         0.01             2.3      0.065
# 179            6.9             0.410         0.33             2.2      0.081
# 225            7.0             0.620         0.18             1.5      0.062
# 73             7.4             0.580         0.00             2.0      0.064
# 245            7.7             0.560         0.20             2.0      0.075
# 196           10.4             0.280         0.54             2.7      0.105
# 2              7.5             0.400         0.12             3.0      0.092
# 233            8.9             0.840         0.34             1.4      0.050
# 102            7.3             0.305         0.39             1.2      0.059
# 95             6.7             0.750         0.01             2.4      0.078
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...
