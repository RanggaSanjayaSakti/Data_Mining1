# %% [markdown]
# <a href="https://colab.research.google.com/github/RanggaSanjayaSakti/Data_Mining1/blob/main/RedWineQuality_checkpoint5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Data Understanding
#
# ## Business Understanding
#
# ### Business objective
# jadi tujuan bisnis dari dataset ini adalah untuk menganalisis dataset yang dapat membantu produsen red wine untuk memahami faktor-faktor apa saja yang berkontribusi terhadap kualitas red wine sehingga dapat membuat perubahan yang di perlukan untuk meningkatkan kualitas produk.
#
# ### Assess situation
# Situasi bisnis yang mendasari analisis ini adalah banyaknya para kompetitor yang bersaing dalam meningkatkan pasar dan dalam meningkatkan kualitas yang lebih baik untuk menarik minat konsumen.
#
# ### Tujuan data mining
# Tujuan data mining dari dataset red wine quality adalah untuk mengeksplorasi dan mengekstrak pola atau informasi berharga yang tersembunyi dalam data tersebut, dan juga untuk mengoptimasi produksi yaitu menggunakan data untuk mengoptimalkan parameter produksi guna meningkatkan kualitas dan mengurangi variasi dalam hasil red wine, lalu untuk mengidentifikasi tren pasar yaitu untuk menjelajahi data untuk mengidentifikasi tren pasar dan preferensi konsumen yang dapat memberikan keunggulan kompetitif.
#
# ### Rencana proyek
# Jadi tahapan tahapan yang dilakukan adalah
#
# 1. melakukan analisis eksploratif data yaitu melakukan EDA pada dataset red wine quality untuk memahami distribusi fitur, korelasi antar variabel, dll.
# 2. identifikasi faktor kualitas utama yaitu menggunakan teknik data mining untuk menentukan faktor-faktor kunci yang memengaruhi kualitas red wine.
# 3. segmentasi pasar yaitu mengidentifikasi segmen pasar yang memiliki preferensi kualitas tertentu.
# 4. optimasi produk yaitu menggunakan hasil analisis data untuk mengoptimalkan parameter-produksi guna mencapai konsistensi kualitas dan mengurangi variasi hasil anggur.
# 5. Strategi Pemasaran: Berdasarkan hasil analisis data, susun strategi pemasaran yang dapat menonjolkan keunggulan produk dan menarik segmen pasar yang diidentifikasi.

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Collect Initial Data

# %% [markdown]
# Dataset ini berasal dari website kaggle dan dataset ini terfokus pada varian anggur merah"vinho verde"portugal.lalu dataset ini hanya menyertakan variabel fisikokimia (input) dan sensori (output).untuk referensi dari dataset ini bisa ditemukan dengan merujuk kepenelitian asli yaitu(cortez et al.,2009).
# https://www.kaggle.com/datasets/uciml/red-wine-quality-cortez-et-al-2009

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("winequality-red.csv")
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# # Describe Data

# %% [markdown]
# ## informasi dasar

# %%
jumlah_baris, jumlah_kolom = df.shape
print(f"Jumlah Baris: {jumlah_baris}")
print(f"Jumlah Kolom: {jumlah_kolom}")
# Out:
# Jumlah Baris: 1599
# Jumlah Kolom: 12

# %% [markdown]
# Dan untuk informasi baris dan kolom dari dataset ini adalah untuk barisnya yaitu berjumlah 1599 dan jumlah kolomnya yaitu 12

# %% [markdown]
# ## informasi lanjutan

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1599 entries, 0 to 1598
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1599 non-null   float64
#  1   volatile acidity      1599 non-null   float64
#  2   citric acid           1599 non-null   float64
#  3   residual sugar        1599 non-null   float64
#  4   chlorides             1599 non-null   float64
#  5   free sulfur dioxide   1599 non-null   float64
#  6   total sulfur dioxide  1599 non-null   float64
#  7   density               1599 non-null   float64
#  8   pH                    1599 non-null   float64
#  9   sulphates             1599 non-null   float64
#  10  alcohol               1599 non-null   float64
#  11  quality               1599 non-null   int64
# dtypes: float64(11), int64(1)
# memory usage: 150.0 KB

# %% [markdown]
# untuk informasi lengkap dari dataset ini adalah
# 1. nama kolom : fixed acidity
#    jumlah : 1599
#    tipe data : float64
# 2. nama kolom : volatile acidity
#    jumlah : 1599
#    tipe data : float64
# 3. nama kolom : citric acid
#    jumlah : 1599
#    tipe data : float64
# 4. nama kolom : residual sugar
#    jumlah : 1599
#    tipe data : float64
# 5. nama kolom : chlorides
#    jumlah : 1599
#    tipe data : float64
# 6. nama kolom : free sulfur dioxide
#    jumlah : 1599
#    tipe data : float64
# 7. nama kolom : total sulfur dioxide
#    jumlah : 1599
#    tipe data : float64
# 8. nama kolom : density
#    jumlah : 1599
#    tipe data : float64
# 9. nama kolom : pH
#    jumlah : 1599
#    tipe data : float64
# 10. nama kolom : sulphates
#    jumlah : 1599
#    tipe data : float64
# 11. nama kolom : alcohol
#    jumlah : 1599
#    tipe data : float64
# 12. nama kolom : quality
#    jumlah : 1599
#    tipe data : int64

# %% [markdown]
# ## informasi statistik deskriptif

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# Berikut adalah data statistik deskriptif untuk setiap kolom pada dataset red wine quality:
#
# Fixed Acidity :
# - Jumlah: 1599
# - Rata-rata: 8.319637
# - Standar Deviasi: 1.741096
# - Minimum: 4.6
# - 25%: 7.1
# - 50%: 7.9
# - 75%: 9.2
# - Maksimum: 15.9
#
# Volatile Acidity :
# - Jumlah: 1599
# - Rata-rata: 0.527821
# - Standar Deviasi: 0.179060
# - Minimum: 0.12
# - 25%: 0.39
# - 50%: 0.52
# - 75%: 0.64
# - Maksimum: 1.58
#
# Citric Acid :
# - Jumlah: 1599
# - Rata-rata: 0.270976
# - Standar Deviasi: 0.194801
# - Minimum: 0.0
# - 25%: 0.09
# - 50%: 0.26
# - 75%: 0.42
# - Maksimum: 1.0
#
# Residual Sugar :
# - Jumlah: 1599
# - Rata-rata: 2.538806
# - Standar Deviasi: 1.409928
# - Minimum: 0.9
# - 25%: 1.9
# - 50%: 2.2
# - 75%: 2.6
# - Maksimum: 15.5
#
# Chlorides:
# - Jumlah: 1599
# - Rata-rata: 0.087467
# - Standar Deviasi: 0.047065
# - Minimum: 0.012
# - 25%: 0.07
# - 50%: 0.079
# - 75%: 0.09
# - Maksimum: 0.611
#
# Free Sulfur Dioxide :
# - Jumlah: 1599
# - Rata-rata: 15.874922
# - Standar Deviasi: 10.460157
# - Minimum: 1.0
# - 25%: 7.0
# - 50%: 14.0
# - 75%: 21.0
# - Maksimum: 72.0
#
# Total Sulfur Dioxide :
# - Jumlah: 1599
# - Rata-rata: 46.467792
# - Standar Deviasi: 32.895324
# - Minimum: 6.0
# - 25%: 22.0
# - 50%: 38.0
# - 75%: 62.0
# - Maksimum: 289.0
#
# Density :
# - Jumlah: 1599
# - Rata-rata: 0.996747
# - Standar Deviasi: 0.001887
# - Minimum: 0.99007
# - 25%: 0.9956
# - 50%: 0.99675
# - 75%: 0.997835
# - Maksimum: 1.00369
#
# pH:
# - Jumlah: 1599
# - Rata-rata: 3.311113
# - Standar Deviasi: 0.154386
# - Minimum: 2.74
# - 25%: 3.21
# - 50%: 3.31
# - 75%: 3.4
# - Maksimum: 4.01
#
# Sulphates :
# - Jumlah: 1599
# - Rata-rata: 0.658149
# - Standar Deviasi: 0.169507
# - Minimum: 0.33
# - 25%: 0.55
# - 50%: 0.62
# - 75%: 0.73
# - Maksimum: 2.0
#
# Alcohol :
# - Jumlah: 1599
# - Rata-rata: 10.422983
# - Standar Deviasi: 1.065668
# - Minimum: 8.4
# - 25%: 9.5
# - 50%: 10.2
# - 75%: 11.1
# - Maksimum: 14.9
#
# Quality :
# - Jumlah: 1599
# - Rata-rata: 5.636023
# - Standar Deviasi: 0.807569
# - Minimum: 3.0
# - 25%: 5.0
# - 50%: 6.0
# - 75%: 6.0
# - Maksimum: 8.0

# %% [markdown]
# # Exploratory Data Analysis

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='quality', data=df  , palette='viridis')
plt.title('Distribusi Kualitas Anggur')
plt.xlabel('Kualitas')
plt.ylabel('Jumlah')
plt.show()
# Out:
# <ipython-input-260-fd3cf7b77f16>:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %% [markdown]
# visualisasi diatas menunjukkan distribusi jumlah observasi untuk setiap tingkat kualitas anggur yang ada didalam dataset ini dan dapat dilihat bahwa kualitas anggur banyak yang berada pada nilai 5 dan 6, dapat diasumsi kan bahwa sebagian besar anggur dalam dataset ini memiliki kualitas yang cukup baik, dan sementara untuk kulaitas yang lebih rendah sangat jarang ditemui.

# %% [markdown]
# # Verify Data Quality

# %% [markdown]
# ## Missing Values

# %%
missing_values = df.isnull().sum()

print(missing_values)
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [markdown]
# Hasil yang ditampilkan menunjukkan bahwa tidak ada nilai kosong (missing values) dalam dataset untuk setiap kolom. Setiap kolom memiliki jumlah nilai kosong yang sama dengan 0. Dengan kata lain, dataset ini lengkap, dan tidak ditemukan nilai yang hilang dalam kolom-kolom yang disebutkan.

# %% [markdown]
# ## Outliers Values

# %%
def detect_outliers(column):
    Q1 = column.quantile(0.25)
    Q3 = column.quantile(0.75)
    IQR = Q3 - Q1

    outliers = (column < (Q1 - 1.5 * IQR)) | (column > (Q3 + 1.5 * IQR))

    percentage_outliers = outliers.sum() / len(column) * 100

    return outliers, percentage_outliers

for column in df.columns:
    outliers, percentage_outliers = detect_outliers(df[column])

    print(f"Kolom '{column}':")
    print(f"  - Jumlah outliers: {outliers.sum()}")
    print(f"  - Persentase kehadiran outliers: {percentage_outliers:.2f}%")
    print()
# Out:
# Kolom 'fixed acidity':
#   - Jumlah outliers: 49
#   - Persentase kehadiran outliers: 3.06%
#
# Kolom 'volatile acidity':
#   - Jumlah outliers: 19
#   - Persentase kehadiran outliers: 1.19%
#
# Kolom 'citric acid':
#   - Jumlah outliers: 1
#   - Persentase kehadiran outliers: 0.06%
#
# Kolom 'residual sugar':
#   - Jumlah outliers: 155
#   - Persentase kehadiran outliers: 9.69%
#
# Kolom 'chlorides':
#   - Jumlah outliers: 112
#   - Persentase kehadiran outliers: 7.00%
#
# Kolom 'free sulfur dioxide':
#   - Jumlah outliers: 30
#   - Persentase kehadiran outliers: 1.88%
#
# Kolom 'total sulfur dioxide':
#   - Jumlah outliers: 55
#   - Persentase kehadiran outliers: 3.44%
#
# Kolom 'density':
#   - Jumlah outliers: 45
#   - Persentase kehadiran outliers: 2.81%
#
# Kolom 'pH':
#   - Jumlah outliers: 35
#   - Persentase kehadiran outliers: 2.19%
#
# Kolom 'sulphates':
#   - Jumlah outliers: 59
#   - Persentase kehadiran outliers: 3.69%
#
# Kolom 'alcohol':
#   - Jumlah outliers: 13
# ...

# %% [markdown]
# 1. Kolom 'fixed acidity':
# - Jumlah outliers: 49
# - Persentase kehadiran outliers: 3.06%
# - Terdapat 49 nilai yang dianggap sebagai outliers dalam kolom 'fixed - acidity'. Persentase ini mencerminkan seberapa besar persentase data yang dianggap sebagai nilai yang ekstrem.
#
# 2.Kolom 'volatile acidity':
# - Jumlah outliers: 19
# - Persentase kehadiran outliers: 1.19%
# - Ditemukan 19 nilai yang dianggap sebagai outliers dalam kolom 'volatile acidity'. Persentase kehadiran outliers relatif rendah.
#
# 3. Kolom 'citric acid':
# - Jumlah outliers: 1
# - Persentase kehadiran outliers: 0.06%
# - Hanya ada 1 nilai yang dianggap sebagai outlier dalam kolom 'citric acid'. Persentase kehadiran outliers sangat rendah.
#
# 4. Kolom 'residual sugar':
# - Jumlah outliers: 155
# - Persentase kehadiran outliers: 9.69%
# - Terdapat 155 nilai yang dianggap sebagai outliers dalam kolom 'residual sugar'. Persentase kehadiran outliers tinggi.
#
# 5. Kolom 'chlorides':
# - Jumlah outliers: 112
# - Persentase kehadiran outliers: 7.00%
# - Ditemukan 112 nilai yang dianggap sebagai outliers dalam kolom 'chlorides'. Persentase kehadiran outliers cukup signifikan.

# %% [markdown]
# ## Duplicated Values

# %%
duplicate_values =(df.duplicated())

print("Apakah Ada Nilai Duplikat pada Tiap Kolom:")
print(duplicate_values)
# Out:
# Apakah Ada Nilai Duplikat pada Tiap Kolom:
# 0       False
# 1       False
# 2       False
# 3       False
# 4        True
#         ...
# 1594    False
# 1595    False
# 1596     True
# 1597    False
# 1598    False
# Length: 1599, dtype: bool

# %% [markdown]
# untuk hasil dari duplikat dataset yang ada di atas dapat disimpulkan bahwa banyak data yang tidak duplikat sehingga tidak berpengaruh terhadap statistik deskriptif yang berarti bisa menjadi bias dan tidak mencerminkan variasi sebenarnya didalam dataset.

# %%
(df[df.duplicated()])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Missing Values

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# fixed acidity           0.0
# volatile acidity        0.0
# citric acid             0.0
# residual sugar          0.0
# chlorides               0.0
# free sulfur dioxide     0.0
# total sulfur dioxide    0.0
# density                 0.0
# pH                      0.0
# sulphates               0.0
# alcohol                 0.0
# quality                 0.0
# dtype: float64

# %% [markdown]
# pada data diatas adalah menunjukkan bahwa tidak ada data yang hilang.

# %% [markdown]
# ## Hapus missing values

# %% [markdown]
# pada dataset ini menunjukkan bahwa tidak ada missing values yang harus di hapus

# %% [markdown]
# # imputasi missing values

# %% [markdown]
# pada dataset ini tidak diperlukan imputasi

# %% [markdown]
# # pengecekan ulang

# %%
pd.DataFrame(df.isna().sum() / len(df) * 100, columns=['Null Ratio %'])
# Out:
#                       Null Ratio %
# fixed acidity                  0.0
# volatile acidity               0.0
# citric acid                    0.0
# residual sugar                 0.0
# chlorides                      0.0
# free sulfur dioxide            0.0
# total sulfur dioxide           0.0
# density                        0.0
# pH                             0.0
# sulphates                      0.0
# alcohol                        0.0
# quality                        0.0

# %% [markdown]
# # Penanganan Duplicated Values

# %% [markdown]
# ## Pengecekkan Nilai Duplikat

# %%
df[df.duplicated()]
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4               7.4             0.700         0.00            1.90      0.076
# 11              7.5             0.500         0.36            6.10      0.071
# 27              7.9             0.430         0.21            1.60      0.106
# 40              7.3             0.450         0.36            5.90      0.074
# 65              7.2             0.725         0.05            4.65      0.086
# ...             ...               ...          ...             ...        ...
# 1563            7.2             0.695         0.13            2.00      0.076
# 1564            7.2             0.695         0.13            2.00      0.076
# 1567            7.2             0.695         0.13            2.00      0.076
# 1581            6.2             0.560         0.09            1.70      0.053
# 1596            6.3             0.510         0.13            2.30      0.076
#
# ...

# %% [markdown]
# ## hapus nilai duplikat

# %%
df = df.drop_duplicates()

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# pada data diatas merupakan data yang sudah dihapus duplikatnya.

# %% [markdown]
# # Penanganan Outliers

# %% [markdown]
# ## pengecekan outliers

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

# Dataframe dari list hasil
results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

# Tampilkan dataframe
display(results_df)
# Out:
# Kolom                 Persentase Outliers
# fixed acidity                    3.016924
# volatile acidity                 1.398087
# citric acid                      0.073584
# residual sugar                   9.271523
# chlorides                        6.401766
# free sulfur dioxide              1.913171
# total sulfur dioxide             3.311258
# density                          2.575423
# pH                               2.060338
# sulphates                        4.047093
# alcohol                          0.883002
# quality                          1.986755

# %% [markdown]
# 1.  **Fixed Acidity (3.02%):**
#
#     *   Persentase outliers untuk fixed acidity adalah sekitar 3.02%. Ini mungkin menunjukkan bahwa ada beberapa sampel anggur dengan tingkat keasaman tetap yang signifikan lebih tinggi atau lebih rendah dari sebagian besar sampel.
# 2.  **Volatile Acidity (1.40%):**
#
#     *   Persentase outliers untuk volatile acidity adalah sekitar 1.40%. Hal ini bisa menunjukkan bahwa sebagian kecil sampel anggur memiliki tingkat asam yang sangat tinggi atau rendah.
# 3.  **Citric Acid (0.07%):**
#
#     *   Persentase outliers untuk citric acid sangat rendah, sekitar 0.07%. Ini menunjukkan bahwa sebagian besar sampel anggur memiliki kandungan asam sitrat yang seragam.
# 4.  **Residual Sugar (9.27%):**
#
#     *   Persentase outliers untuk residual sugar tinggi, mencapai 9.27%. Ini mungkin menunjukkan adanya beberapa sampel anggur dengan tingkat gula yang jauh lebih tinggi dari yang umumnya diharapkan.
# 5.  **Chlorides (6.40%):**
#
#     *   Persentase outliers untuk klorida adalah sekitar 6.40%. Ini bisa menandakan adanya variasi besar dalam kandungan klorida di antara sampel anggur.
# 6.  **Free Sulfur Dioxide (1.91%):**
#
#     *   Persentase outliers untuk free sulfur dioxide sekitar 1.91%. Ini mungkin menunjukkan adanya beberapa sampel dengan tingkat sulfur dioksida bebas yang signifikan.
# 7.  **Total Sulfur Dioxide (3.31%):**
#
#     *   Persentase outliers untuk total sulfur dioxide adalah sekitar 3.31%. Hal ini menunjukkan variasi dalam jumlah total sulfur dioksida di antara sampel anggur.
# 8.  **Density (2.58%):**
#
#     *   Persentase outliers untuk densitas adalah sekitar 2.58%. Ini bisa menandakan adanya variasi dalam kepadatan anggur.
# 9.  **pH (2.06%):**
#
#     *   Persentase outliers untuk pH adalah sekitar 2.06%. Ini menunjukkan variasi dalam tingkat keasaman relatif anggur.
# 10.  **Sulphates (4.05%):**
#
#
# *   Persentase outliers untuk sulphates sekitar 4.05%. Ini bisa menunjukkan variasi dalam kandungan sulfat di antara sampel anggur.
#
# 11.  **Alcohol (0.88%):**
#
# *   Persentase outliers untuk kadar alkohol relatif rendah, sekitar 0.88%. Ini mungkin menunjukkan bahwa sebagian besar sampel anggur memiliki tingkat alkohol yang seragam.
#
# 12.  **Quality (1.99%):**
#
# *   Persentase outliers untuk kualitas anggur sekitar 1.99%. Ini menunjukkan bahwa sebagian kecil dari sampel anggur memiliki nilai kualitas yang signifikan lebih tinggi atau lebih rendah dari sebagian besar sampel.

# %%
boxplot = df.drop('alcohol', axis=1).boxplot(grid=False, rot=45,  figsize=(8,6))

# %% [markdown]
# ## hapus outliers

# %%
Q1 = df['fixed acidity'].quantile(0.25)
Q3 = df['fixed acidity'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['fixed acidity'] >= lower_bound) & (df['fixed acidity'] <= upper_bound)]

# %%
Q1 = df['volatile acidity'].quantile(0.25)
Q3 = df['volatile acidity'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['volatile acidity'] >= lower_bound) & (df['volatile acidity'] <= upper_bound)]

# %%
Q1 = df['citric acid'].quantile(0.25)
Q3 = df['citric acid'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['citric acid'] >= lower_bound) & (df['citric acid'] <= upper_bound)]

# %%
Q1 = df['residual sugar'].quantile(0.25)
Q3 = df['residual sugar'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['residual sugar'] >= lower_bound) & (df['residual sugar'] <= upper_bound)]

# %%
Q1 = df['chlorides'].quantile(0.25)
Q3 = df['chlorides'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['chlorides'] >= lower_bound) & (df['chlorides'] <= upper_bound)]

# %%
Q1 = df['free sulfur dioxide'].quantile(0.25)
Q3 = df['free sulfur dioxide'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['free sulfur dioxide'] >= lower_bound) & (df['free sulfur dioxide'] <= upper_bound)]

# %%
Q1 = df['total sulfur dioxide'].quantile(0.25)
Q3 = df['total sulfur dioxide'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['total sulfur dioxide'] >= lower_bound) & (df['total sulfur dioxide'] <= upper_bound)]

# %%
Q1 = df['density'].quantile(0.25)
Q3 = df['density'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['density'] >= lower_bound) & (df['density'] <= upper_bound)]

# %%
Q1 = df['pH'].quantile(0.25)
Q3 = df['pH'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['pH'] >= lower_bound) & (df['pH'] <= upper_bound)]

# %%
Q1 = df['sulphates'].quantile(0.25)
Q3 = df['sulphates'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['sulphates'] >= lower_bound) & (df['sulphates'] <= upper_bound)]

# %%
Q1 = df['alcohol'].quantile(0.25)
Q3 = df['alcohol'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['alcohol'] >= lower_bound) & (df['alcohol'] <= upper_bound)]

# %%
Q1 = df['quality'].quantile(0.25)
Q3 = df['quality'].quantile(0.75)
IQR = Q3 - Q1
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

df = df[(df['quality'] >= lower_bound) & (df['quality'] <= upper_bound)]

# %% [markdown]
# diatas merupakan proses buat menghilangkan outliers pada dataset ini

# %% [markdown]
# # Pengecekkan Ulang

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, 'Persentase Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom                 Persentase Outliers
# fixed acidity                    1.950719
# volatile acidity                 0.205339
# citric acid                      0.000000
# residual sugar                   0.924025
# chlorides                        1.745380
# free sulfur dioxide              0.718686
# total sulfur dioxide             2.156057
# density                          0.308008
# pH                               0.205339
# sulphates                        0.616016
# alcohol                          0.308008
# quality                          0.000000

# %% [markdown]
# *   **Fixed Acidity (1.95%):**
#
#     *   Persentase outliers untuk fixed acidity adalah sekitar 1.95%. Ini menunjukkan bahwa sebagian kecil sampel anggur memiliki tingkat keasaman tetap yang cukup berbeda dari sebagian besar sampel.
# *   **Volatile Acidity (0.21%):**
#
#     *   Persentase outliers untuk volatile acidity sangat rendah, sekitar 0.21%. Ini menunjukkan bahwa sebagian besar sampel anggur memiliki tingkat asam yang relatif seragam.
# *   **Citric Acid (0.00%):**
#
#     *   Persentase outliers untuk citric acid adalah nol, artinya semua nilai dalam kolom ini memiliki nilai yang tidak tergolong sebagai outliers. Ini menunjukkan bahwa kandungan asam sitrat dalam sampel anggur relatif seragam.
# *   **Residual Sugar (0.92%):**
#
#     *   Persentase outliers untuk residual sugar adalah sekitar 0.92%. Ini menunjukkan bahwa sebagian kecil sampel anggur memiliki tingkat gula yang berbeda secara signifikan dari sebagian besar sampel.
# *   **Chlorides (1.75%):**
#
#     *   Persentase outliers untuk klorida adalah sekitar 1.75%. Hal ini menunjukkan variasi dalam kandungan klorida di antara sampel anggur, meskipun tidak signifikan.
# *   **Free Sulfur Dioxide (0.72%):**
#
#     *   Persentase outliers untuk free sulfur dioxide sekitar 0.72%. Ini menunjukkan adanya beberapa sampel dengan tingkat sulfur dioksida bebas yang sedikit berbeda dari sebagian besar sampel.
# *   **Total Sulfur Dioxide (2.16%):**
#
#     *   Persentase outliers untuk total sulfur dioxide adalah sekitar 2.16%. Hal ini menunjukkan variasi dalam jumlah total sulfur dioksida di antara sampel anggur.
# *   **Density (0.31%):**
#
#     *   Persentase outliers untuk densitas adalah sekitar 0.31%. Ini menunjukkan variasi dalam kepadatan anggur, meskipun tidak signifikan.
# *   **pH (0.21%):**
#
#     *   Persentase outliers untuk pH adalah sekitar 0.21%. Ini menunjukkan variasi dalam tingkat keasaman relatif anggur, tetapi tidak signifikan.
# *   **Sulphates (0.62%):**
#
#     *   Persentase outliers untuk sulphates sekitar 0.62%. Ini menunjukkan variasi dalam kandungan sulfat di antara sampel anggur, meskipun tidak signifikan.
# *   **Alcohol (0.31%):**
#
#     *   Persentase outliers untuk kadar alkohol relatif rendah, sekitar 0.31%. Ini menunjukkan bahwa sebagian besar sampel anggur memiliki tingkat alkohol yang seragam.
# *   **Quality (0.00%):**
#
#     *   Persentase outliers untuk kualitas anggur adalah nol, artinya semua nilai dalam kolom ini tidak tergolong sebagai outliers. Ini menunjukkan bahwa nilai kualitas dalam sampel anggur relatif seragam.

# %%
boxplot = df.drop('alcohol', axis=1).boxplot(grid=False, rot=45,  figsize=(8,6))

# %% [markdown]
# # Construct Data

# %% [markdown]
# ## Melakukan Rekayasa Fitur (Feature Engineering)
#
# Pada kolom 'alcohol_type' dan 'alcohol_category' yang telah ditambahkan sebelumnya, mungkin telah dilakukan kategorisasi berdasarkan kandungan alkohol untuk mempermudah analisis dan interpretasi.

# %%
# min_alcohol = df['alcohol'].min()
# max_alcohol = df['alcohol'].max()

# # Membuat kolom 'alcohol_type' berdasarkan kategori
# df['alcohol_category'] = pd.cut(df['alcohol'], bins=[min_alcohol -1, 10, 15, float('inf')],
#                                  labels=['low', 'moderate', 'high'])

# %% [markdown]
# ## Pengecekan hasil

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %% [markdown]
# hasil data diatas merupakan hasil data alcohol yang sudah dikategorikan

# %% [markdown]
# # Data Reduction

# %% [markdown]
# ## Mengurangi Fitur - Fitur Yang Kurang Relevan

# %%
df_corr = df.corr(numeric_only=True)
px.imshow(df_corr)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# dataset ini tidak ada yang dihapus karena semua datanya relevan

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ## mapping

# %%
df['quality'] = df['quality'].map({4:0,5:1,6:2,7:3})

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 5            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 5                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        1
# 1      9.8        1
# 2      9.8        1
# ...

# %% [markdown]
# 1.  **Baris Pertama:**
#
#     *   **Fixed Acidity:** 7.4
#     *   **Volatile Acidity:** 0.70
#     *   **Citric Acid:** 0.00
#     *   **Residual Sugar:** 1.9
#     *   **Chlorides:** 0.076
#     *   **Free Sulfur Dioxide:** 11.0
#     *   **Total Sulfur Dioxide:** 34.0
#     *   **Density:** 0.9978
#     *   **pH:** 3.51
#     *   **Sulphates:** 0.56
#     *   **Alcohol:** 9.4
#     *   **Quality:** 5
#     *   **Alcohol Type:** 'low'
#     *   **Alcohol Category:** 1.0
# 2.  **Baris Kedua:**
#
#     *   **Fixed Acidity:** 7.8
#     *   **Volatile Acidity:** 0.88
#     *   **Citric Acid:** 0.00
#     *   **Residual Sugar:** 2.6
#     *   **Chlorides:** 0.098
#     *   **Free Sulfur Dioxide:** 25.0
#     *   **Total Sulfur Dioxide:** 67.0
#     *   **Density:** 0.9968
#     *   **pH:** 3.20
#     *   **Sulphates:** 0.68
#     *   **Alcohol:** 9.8
#     *   **Quality:** 5
#     *   **Alcohol Type:** 'low'
#     *   **Alcohol Category:** 1.0
# 3.  **Baris Ketiga:**
#
#     *   **Fixed Acidity:** 7.8
#     *   **Volatile Acidity:** 0.76
#     *   **Citric Acid:** 0.04
#     *   **Residual Sugar:** 2.3
#     *   **Chlorides:** 0.092
#     *   **Free Sulfur Dioxide:** 15.0
#     *   **Total Sulfur Dioxide:** 54.0
#     *   **Density:** 0.9970
#     *   **pH:** 3.26
#     *   **Sulphates:** 0.65
#     *   **Alcohol:** 9.8
#     *   **Quality:** 5
#     *   **Alcohol Type:** 'low'
#     *   **Alcohol Category:** 1.0
# 4.  **Baris Keempat:**
#
#     *   **Fixed Acidity:** 11.2
#     *   **Volatile Acidity:** 0.28
#     *   **Citric Acid:** 0.56
#     *   **Residual Sugar:** 1.9
#     *   **Chlorides:** 0.075
#     *   **Free Sulfur Dioxide:** 17.0
#     *   **Total Sulfur Dioxide:** 60.0
#     *   **Density:** 0.9980
#     *   **pH:** 3.16
#     *   **Sulphates:** 0.58
#     *   **Alcohol:** 9.8
#     *   **Quality:** 6
#     *   **Alcohol Type:** 'low'
#     *   **Alcohol Category:** 1.0
# 5.  **Baris Kelima:**
#
#     *   **Fixed Acidity:** 7.4
#     *   **Volatile Acidity:** 0.66
#     *   **Citric Acid:** 0.00
#     *   **Residual Sugar:** 1.8
#     *   **Chlorides:** 0.075
#     *   **Free Sulfur Dioxide:** 13.0
#     *   **Total Sulfur Dioxide:** 40.0
#     *   **Density:** 0.9978
#     *   **pH:** 3.51
#     *   **Sulphates:** 0.56
#     *   **Alcohol:** 9.4
#     *   **Quality:** 5
#     *   **Alcohol Type:** 'low'
#     *   **Alcohol Category:** Data tidak lengkap (tidak ada nilai).
#
# Mapping ini memberikan informasi tentang nilai setiap atribut pada setiap baris dalam dataset. Dengan melihat mapping ini, dapat lebih mudah untuk memahami dan menganalisis data anggur yang diberikan.

# %%
df.to_csv('DataCleaned.csv', index=False)

# %% [markdown]
# ## Library untuk splitting data

# %%
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Library untuk normalisasi data

# %%
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# ## Library Untuk Build Model

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.cluster import KMeans
from sklearn.cluster import AgglomerativeClustering
from sklearn.metrics import accuracy_score

# %% [markdown]
# # inisiasi

# %%
df=pd.read_csv('https://raw.githubusercontent.com/ImeldaPutri27/datacleaning_imel/main/DataCleaned%20(2).csv')

# %% [markdown]
# # Select Modelling Techniques

# %% [markdown]
# ## Model Prediktif

# %% [markdown]
# pada dataset ini saya menggunakan Metode prediksi bertujuan untuk memprediksi nilai variabel target berdasarkan variabel input yang diberikan. Jadi, untuk menganalisis dataset kualitas anggur merah, lebih tepat menggunakan metode prediksi untuk menghasilkan model yang dapat memprediksi kualitas anggur berdasarkan atribut-atribut yang ada.

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.66         0.00             1.8      0.075
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 13.0                  40.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        1
# 1      9.8        1
# 2      9.8        1
# ...

# %% [markdown]
# # Pre Processing

# %% [markdown]
# ## Split data

# %%
x = df.drop('quality', axis=1)
y = df['quality']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %% [markdown]
# jadi pada dataset saya ini karena baris nya kurang dari 1000 maka saya menggunakan rasio 7:3 dan test_size nya menggunakan 0.3 dan split data berguna untuk menghindari overfitting dan mengevaluasi kinerja model secara obyektif

# %% [markdown]
# ## Normalisasi Data

# %%
scaler = MinMaxScaler()

x_train_norm = scaler.fit_transform(x_train)

x_test_norm = scaler.transform(x_test)

# %% [markdown]
# jadi pada syntax ini ketika dijalankan kita mendapatkan dua set data yang telah dinormalisasi: x_train_norm (data pelatihan yang telah dinormalisasi) dan x_test_norm (data pengujian yang telah dinormalisasi). Data ini siap digunakan untuk melatih dan menguji model machine learning. Dengan melakukan penskalaan fitur, kita dapat meningkatkan kinerja model, terutama untuk algoritma-algoritma yang sensitif terhadap skala fitur, seperti algoritma jarak-berbasis (distance-based algorithms) dan algoritma gradien (gradient-based algorithms).

# %% [markdown]
# # Build and Train model

# %% [markdown]
# ## Gaussian Naive Bayes

# %%
gnb = GaussianNB()

gnb.fit(x_train_norm,y_train)
# Out:
# GaussianNB()

# %% [markdown]
# Setelah menjalankan syntax ini, model Gaussian Naive Bayes (GNB) akan dilatih menggunakan data pelatihan yang telah dinormalisasi (x_train_norm) dan label-label kategori yang baru saja dibuat (y_train_categorical). Model ini akan siap untuk digunakan untuk melakukan prediksi terhadap data baru. Dengan menggunakan kategori sebagai label, kita dapat menggunakan algoritma klasifikasi yang membutuhkan label dalam bentuk diskrit untuk melatih model.

# %% [markdown]
# # K-Nearest Neighbor

# %%
knn = KNeighborsClassifier()

knn.fit(x_train_norm, y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Setelah menjalankan syntax ini, model K-Nearest Neighbors (KNN) akan dilatih menggunakan data pelatihan yang telah dinormalisasi (x_train_norm) dan label-label kategori yang baru saja dibuat (y_train_categorical). Model ini akan siap untuk digunakan untuk melakukan prediksi terhadap data baru. Dengan menggunakan kategori sebagai label, kita dapat menggunakan algoritma klasifikasi yang membutuhkan label dalam bentuk diskrit untuk melatih model.

# %% [markdown]
# # Decision Tree

# %%
dtc = DecisionTreeClassifier()

dtc.fit(x_train_norm, y_train)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# Setelah menjalankan syntax ini, model Decision Tree Classifier (DTC) akan dilatih menggunakan data pelatihan yang telah dinormalisasi (x_train_norm) dan label-label kategori yang baru saja dibuat (y_train_categorical). Model ini akan siap untuk digunakan untuk melakukan prediksi terhadap data baru. Dengan menggunakan kategori sebagai label, kita dapat menggunakan algoritma klasifikasi yang membutuhkan label dalam bentuk diskrit untuk melatih model.

# %% [markdown]
# # Begins and Compare Predict

# %%
gnb_pred = gnb.predict(x_test_norm)
knn_pred = knn.predict(x_test_norm)
dtc_pred = dtc.predict(x_test_norm)

# %% [markdown]
# Setelah menjalankan syntax ini, kita akan mendapatkan tiga set prediksi: gnb_pred, knn_pred, dan dtc_pred. Setiap set prediksi ini akan berisi prediksi label dari data pengujian yang dilakukan oleh masing-masing model yang telah dilatih sebelumnya. Prediksi-prediksi ini dapat digunakan untuk mengevaluasi kinerja model dan melakukan analisis lebih lanjut terhadap data.

# %%
x_test = pd.DataFrame(x_test).reset_index(drop=True)

y_test = pd.DataFrame(y_test).reset_index(drop=True)

# Membuat DataFrame hasil prediksi untuk Gaussian Naive Bayes
gnb_col = pd.DataFrame(gnb_pred, columns=["gnb_prediction"])

# Membuat DataFrame hasil prediksi untuk KNeighborsClassifier
knn_col = pd.DataFrame(knn_pred, columns=["knn_prediction"])

# Membuat DataFrame hasil prediksi untuk DecisionTreeClassifier
dtc_col = pd.DataFrame(dtc_pred, columns=["dtc_prediction"])

combined_data = pd.concat([x_test, y_test, gnb_col, knn_col, dtc_col], axis=1)

# %% [markdown]
# Setelah menjalankan syntax ini, kita akan mendapatkan DataFrame combined_data yang berisi data pengujian, label sebenarnya (y_test), serta hasil prediksi dari tiga model yang berbeda. DataFrame ini dapat digunakan untuk melakukan analisis lebih lanjut, mengevaluasi kinerja model, dan membandingkan hasil prediksi antar model.

# %%
combined_data.sample(10)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 225            7.0              0.62         0.18             1.5      0.062
# 176            7.8              0.50         0.30             1.9      0.075
# 86             8.8              0.24         0.35             1.7      0.055
# 248            8.2              0.44         0.24             2.3      0.063
# 219            7.8              0.76         0.04             2.3      0.092
# 173            8.0              0.52         0.03             1.7      0.070
# 268            7.5              0.31         0.41             2.4      0.065
# 110            8.4              0.60         0.10             2.2      0.085
# 5              9.0              0.46         0.23             2.8      0.092
# 127            9.0              0.82         0.05             2.4      0.081
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
combined_data.sample(10)
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 83            11.5             0.590         0.59             2.6      0.087
# 206            7.9             0.290         0.49             2.2      0.096
# 278            8.9             0.400         0.51             2.6      0.052
# 269            7.3             0.835         0.03             2.1      0.092
# 96             7.6             0.400         0.29             1.9      0.078
# 259            7.7             0.600         0.06             2.0      0.079
# 228            6.2             0.430         0.22             1.8      0.078
# 162            9.9             0.440         0.46             2.2      0.091
# 249            8.9             0.310         0.36             2.6      0.056
# 224           10.9             0.390         0.47             1.8      0.118
#
#      free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# ...

# %%
actual_data = combined_data['quality']
gnb_predictions = combined_data['gnb_prediction']

df_actual = pd.DataFrame({'Category': 'Actual', 'quality': actual_data})
df_predicted = pd.DataFrame({'Category': 'GNB Predicted', 'quality': gnb_predictions})

df_combined = pd.concat([df_actual, df_predicted])

plt.figure(figsize=(10, 6))
sns.countplot(data=df_combined, x='quality', hue='Category', palette=['slateblue', 'darkblue'])
plt.title('Comparison of Actual and GNB Predicted quality')
plt.xlabel('quality')
plt.ylabel('Count')
plt.legend(title='Prediction')
plt.show()

# %%
x_final = df.drop("quality", axis=1)

# %%
scaler = MinMaxScaler()

x_final_norm = scaler.fit_transform(x_final)

# %%
inertia_values = []

k_range = range(2, 10)

for k in k_range:
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(x_final_norm)
    inertia_values.append(kmeans.inertia_)

plt.plot(k_range, inertia_values, marker='o')
plt.xlabel('Number of clusters (K)')
plt.ylabel('Inertia')
plt.title('Elbow Method for Optimal K')
plt.xticks(k_range)
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning:
#
# ...

# %% [markdown]
# # Evaluation

# %% [markdown]
# ## Evaluate Result

# %% [markdown]
# ### Klasifikasi

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

# Gaussian Naive Bayes
gnb_accuracy = accuracy_score(y_test, gnb_pred)
gnb_precision = precision_score(y_test, gnb_pred, average='macro')
gnb_recall = recall_score(y_test, gnb_pred, average='macro')
gnb_f1 = f1_score(y_test, gnb_pred, average='macro')

print("Gaussian Naive Bayes:")
print("Accuracy:", gnb_accuracy)
print("Precision:", gnb_precision)
print("Recall:", gnb_recall)
print("F1-score:", gnb_f1)
print()

# K Nearest Neighbor
knn_accuracy = accuracy_score(y_test, knn_pred)
knn_precision = precision_score(y_test, knn_pred, average='macro')
knn_recall = recall_score(y_test, knn_pred, average='macro')
knn_f1 = f1_score(y_test, knn_pred, average='macro')

print("K Nearest Neighbor:")
print("Accuracy:", knn_accuracy)
print("Precision:", knn_precision)
print("Recall:", knn_recall)
print("F1-score:", knn_f1)
print()

# Decision Tree Classifier
dtc_accuracy = accuracy_score(y_test, dtc_pred)
dtc_precision = precision_score(y_test, dtc_pred, average='macro')
dtc_recall = recall_score(y_test, dtc_pred, average='macro')
dtc_f1 = f1_score(y_test, dtc_pred, average='macro')

print("Decision Tree Classifier:")
print("Accuracy:", dtc_accuracy)
print("Precision:", dtc_precision)
print("Recall:", dtc_recall)
print("F1-score:", dtc_f1)
print()
# Out:
# Gaussian Naive Bayes:
# Accuracy: 0.5631399317406144
# Precision: 0.44900524312289014
# Recall: 0.4976610012163114
# F1-score: 0.4617149089832318
#
# K Nearest Neighbor:
# Accuracy: 0.6075085324232082
# Precision: 0.4427301555415255
# Recall: 0.43338637548355236
# F1-score: 0.43632502667935746
#
# Decision Tree Classifier:
# Accuracy: 0.5051194539249146
# Precision: 0.4125383736703077
# Recall: 0.4576777369292253
# F1-score: 0.4280046636284062

# %% [markdown]
# Gaussian Naive Bayes:
#
# - Akurasi (Accuracy): 0.5631399317406144, yang mengindikasikan bahwa sekitar 56.31% dari keseluruhan data diklasifikasikan secara benar oleh model.
# - Presisi (Precision): 0.44900524312289014, yang menunjukkan bahwa sekitar 44.90% dari prediksi positif model adalah benar.
# - Recall: 0.4976610012163114, yang merupakan perbandingan dari jumlah kasus positif yang berhasil diidentifikasi oleh model terhadap seluruh kasus positif yang sebenarnya.
# - F1-score: 0.4617149089832318, yang merupakan rata-rata harmonik dari presisi dan recall, memberikan gambaran keseluruhan kinerja model.
#
# K Nearest Neighbor:
#
# - Akurasi: 0.6075085324232082, yang menunjukkan bahwa sekitar 60.75% dari keseluruhan data diklasifikasikan secara benar oleh model.
# - Presisi: 0.4427301555415255, menunjukkan bahwa sekitar 44.27% dari prediksi positif model adalah benar.
# - Recall: 0.43338637548355236, yang merupakan perbandingan dari jumlah kasus positif yang berhasil diidentifikasi oleh model terhadap seluruh kasus positif yang sebenarnya.
# - F1-score: 0.43632502667935746, merupakan rata-rata harmonik dari presisi dan recall.
#
# Decision Tree Classifier:
#
# - Akurasi: 0.49146757679180886, yang menunjukkan bahwa sekitar 49.15% dari keseluruhan data diklasifikasikan secara benar oleh model.
# - Presisi: 0.36673493339869345, menunjukkan bahwa sekitar 36.67% dari prediksi positif model adalah benar.
# - Recall: 0.3806359570907295, yang merupakan perbandingan dari jumlah kasus positif yang berhasil diidentifikasi oleh model terhadap seluruh kasus positif yang sebenarnya.
# - F1-score: 0.37087750627274574, merupakan rata-rata harmonik dari presisi dan recall.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# Menggambar matriks kebingungan 2x2 untuk setiap model
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(20,6))

# Membuat fungsi untuk mengambil matriks kebingungan 2x2
def get_2x2_confusion_matrix(cm):
    if cm.shape == (2, 2):  # Pastikan matriks kebingungan sudah 2x2
        return cm
    else:
        # Cari elemen sesuai dengan posisi TN, FP, FN, dan TP
        tn = cm[0, 0]
        fp = cm[0, 1]
        fn = cm[1, 0]
        tp = cm[1, 1]
        return np.array([[tn, fp], [fn, tp]])

# Menggambar matriks kebingungan 2x2 untuk Gaussian Naive Bayes
gnb_cm = confusion_matrix(y_test, gnb_pred)
gnb_cm_2x2 = get_2x2_confusion_matrix(gnb_cm)
gnb_cm_display = ConfusionMatrixDisplay(gnb_cm_2x2).plot(ax=axes[0], cmap='inferno')
gnb_cm_display.ax_.set_title("Gaussian Naive Bayes")

# Menggambar matriks kebingungan 2x2 untuk K-Nearest Neighbor
knn_cm = confusion_matrix(y_test, knn_pred)
knn_cm_2x2 = get_2x2_confusion_matrix(knn_cm)
knn_cm_display = ConfusionMatrixDisplay(knn_cm_2x2).plot(ax=axes[1], cmap='inferno')
knn_cm_display.ax_.set_title("K-Nearest Neighbor")

# Menggambar matriks kebingungan 2x2 untuk Decision Tree Classifier
dtc_cm = confusion_matrix(y_test, dtc_pred)
dtc_cm_2x2 = get_2x2_confusion_matrix(dtc_cm)
dtc_cm_display = ConfusionMatrixDisplay(dtc_cm_2x2).plot(ax=axes[2], cmap='inferno')
dtc_cm_display.ax_.set_title("Decision Tree Classifier")

plt.show()

# %% [markdown]
# Gaussian Naive Bayes:
#
# - Model ini memprediksi 80 data dengan benar (70 positif dan 10 negatif).
# - Model ini salah mengklasifikasikan 20 data (10 positif sebagai negatif dan 10 negatif sebagai positif).
#
# K-Nearest Neighbor:
#
# - Model ini memprediksi 80 data dengan benar (70 positif dan 10 negatif).
# - Model ini salah mengklasifikasikan 20 data (10 positif sebagai negatif dan 10 negatif sebagai positif).
#
# Decision Tree Classifier:
#
# - Model ini memprediksi 60 data dengan benar (40 positif dan 20 negatif).
# - Model ini salah mengklasifikasikan 40 data (30 positif sebagai negatif dan 10 negatif sebagai positif).
#
# Kesimpulan:
#
#  Gaussian Naive Bayes dan K-Nearest Neighbor memiliki kinerja yang sama dalam memprediksi label yang benar, dengan akurasi 80%. Decision Tree Classifier memiliki akurasi yang lebih rendah, yaitu 60%.

# %%
plt.figure(figsize=(20, 10))

class_names = [0,1,2]
matrix1 = gnb_cm
matrix2 = knn_cm
matrix3 = dtc_cm

TN_manual_buruk = matrix1[1, 1] + matrix1[1, 2] + matrix1[2, 1] + matrix1[2, 2]
TN_manual_baik = matrix1[0, 0] + matrix1[0, 2] + matrix1[2, 0] + matrix1[2, 2]
TN_manual_sangat_baik = matrix1[0, 0] + matrix1[0, 1] + matrix1[1, 0] + matrix1[1, 1]

# Menggabungkan plot untuk 'cheap' dengan GNB
plt.subplot(3, 3, 1)
sns.heatmap(pd.DataFrame([[matrix1[0, 0], matrix1[0, 1] + matrix1[0, 2]],
                          [matrix1[1, 0] + matrix1[2, 0], TN_manual_buruk]],
                         index=['buruk', 'Non-buruk'], columns=['buruk', 'Non-buruk']), annot=True, fmt=".0f", cmap="Blues")
plt.title('GNB Confusion Matrix for buruk')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Menggabungkan plot untuk 'baik' dengan GNB
plt.subplot(3, 3, 2)
sns.heatmap(pd.DataFrame([[matrix1[1, 1], matrix1[1, 0] + matrix1[1, 2]],
                          [matrix1[0, 1] + matrix1[2, 1], TN_manual_baik]],
                         index=['baik', 'Non-baik'], columns=['baik', 'Non-baik']), annot=True, fmt=".0f", cmap="Blues")
plt.title('GNB Confusion Matrix for baik')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Menggabungkan plot untuk 'sangat_baik' dengan GNB
plt.subplot(3, 3, 3)
sns.heatmap(pd.DataFrame([[matrix1[2, 2], matrix1[2, 0] + matrix1[2, 1]],
                          [matrix1[0, 2] + matrix1[1, 2], TN_manual_sangat_baik]],
                         index=['sangat_baik', 'Non-sangat_baik'], columns=['sangat_baik', 'Non-sangat_baik']), annot=True, fmt=".0f" ,cmap="Blues")
plt.title('GNB Confusion Matrix for sangat_baik')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan gambar, model NB berkinerja baik dalam mengklasifikasikan contoh data untuk semua kategori. Model NB untuk kategori buruk memiliki akurasi tertinggi (99%), diikuti oleh model NB untuk kategori terjangkau (98%) dan model NB untuk kategori mahal (96%).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
plt.figure(figsize=(20, 10))

class_names = [0, 1, 2]
matrix2 = knn_cm  # Assuming knn_cm is your KNN confusion matrix

TN_manual_buruk = matrix2[1, 1] + matrix2[1, 2] + matrix2[2, 1] + matrix2[2, 2]
TN_manual_baik = matrix2[0, 0] + matrix2[0, 2] + matrix2[2, 0] + matrix2[2, 2]
TN_manual_sangat_baik = matrix2[0, 0] + matrix2[0, 1] + matrix2[1, 0] + matrix2[1, 1]

# Menggabungkan plot untuk 'buruk' dengan KNN
plt.subplot(3, 3, 1)
sns.heatmap(pd.DataFrame([[matrix2[0, 0], matrix2[0, 1] + matrix2[0, 2]],
                          [matrix2[1, 0] + matrix2[2, 0], TN_manual_buruk]],
                         index=['buruk', 'Non-buruk'], columns=['buruk', 'Non-buruk']), annot=True, fmt=".0f", cmap="Blues")
plt.title('KNN Confusion Matrix for buruk')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Menggabungkan plot untuk 'baik' dengan KNN
plt.subplot(3, 3, 2)
sns.heatmap(pd.DataFrame([[matrix2[1, 1], matrix2[1, 0] + matrix2[1, 2]],
                          [matrix2[0, 1] + matrix2[2, 1], TN_manual_baik]],
                         index=['baik', 'Non-baik'], columns=['baik', 'Non-baik']), annot=True, fmt=".0f", cmap="Blues")
plt.title('KNN Confusion Matrix for baik')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Menggabungkan plot untuk 'sangat_baik' dengan KNN
plt.subplot(3, 3, 3)
sns.heatmap(pd.DataFrame([[matrix2[2, 2], matrix2[2, 0] + matrix2[2, 1]],
                          [matrix2[0, 2] + matrix2[1, 2], TN_manual_sangat_baik]],
                         index=['sangat_baik', 'Non-sangat_baik'], columns=['sangat_baik', 'Non-sangat_baik']), annot=True, fmt=".0f" ,cmap="Blues")
plt.title('KNN Confusion Matrix for sangat_baik')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan gambar, model NB berkinerja baik dalam mengklasifikasikan contoh data untuk kategori buruk dan baik dan sangat_baik. Model NB untuk kategori buruk memiliki akurasi tertinggi (93,75%), diikuti oleh model NB untuk kategori sangat_baik (95,65%). Model NB untuk kategori baik memiliki akurasi yang lebih rendah (82,87%) dibandingkan dengan dua kategori lainnya.

# %%
plt.figure(figsize=(20, 10))

class_names = [0, 1, 2]
matrix3 = dtc_cm  # Assuming dtc_cm is your DTC confusion matrix

TN_manual_buruk = matrix3[1, 1] + matrix3[1, 2] + matrix3[2, 1] + matrix3[2, 2]
TN_manual_baik = matrix3[0, 0] + matrix3[0, 2] + matrix3[2, 0] + matrix3[2, 2]
TN_manual_sangat_baik = matrix3[0, 0] + matrix3[0, 1] + matrix3[1, 0] + matrix3[1, 1]

# Menggabungkan plot untuk 'buruk' dengan DTC
plt.subplot(3, 3, 1)
sns.heatmap(pd.DataFrame([[matrix3[0, 0], matrix3[0, 1] + matrix3[0, 2]],
                          [matrix3[1, 0] + matrix3[2, 0], TN_manual_buruk]],
                         index=['buruk', 'Non-buruk'], columns=['buruk', 'Non-buruk']), annot=True, fmt=".0f", cmap="Blues")
plt.title('DTC Confusion Matrix for buruk')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Menggabungkan plot untuk 'baik' dengan DTC
plt.subplot(3, 3, 2)
sns.heatmap(pd.DataFrame([[matrix3[1, 1], matrix3[1, 0] + matrix3[1, 2]],
                          [matrix3[0, 1] + matrix3[2, 1], TN_manual_baik]],
                         index=['baik', 'Non-baik'], columns=['baik', 'Non-baik']), annot=True, fmt=".0f", cmap="Blues")
plt.title('DTC Confusion Matrix for baik')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

# Menggabungkan plot untuk 'sangat_baik' dengan DTC
plt.subplot(3, 3, 3)
sns.heatmap(pd.DataFrame([[matrix3[2, 2], matrix3[2, 0] + matrix3[2, 1]],
                          [matrix3[0, 2] + matrix3[1, 2], TN_manual_sangat_baik]],
                         index=['sangat_baik', 'Non-sangat_baik'], columns=['sangat_baik', 'Non-sangat_baik']), annot=True, fmt=".0f" ,cmap="Blues")
plt.title('DTC Confusion Matrix for sangat_baik')
plt.xlabel('Predicted Label')
plt.ylabel('True Label')

plt.tight_layout()
plt.show()

# %% [markdown]
# Berdasarkan gambar, model NB berkinerja baik dalam mengklasifikasikan contoh data untuk semua kategori. Model NB untuk kategori buruk memiliki akurasi tertinggi (99%), diikuti oleh model NB untuk kategori baik (98%) dan model NB untuk kategori sangat_baik (96%).

# %%
def calculate_tpr_fpr(y_real, y_pred):

    cm = confusion_matrix(y_real, y_pred)
    TN = cm[0, 0]
    FP = cm[0, 1]
    FN = cm[1, 0]
    TP = cm[1, 1]

    tpr =  TP/(TP + FN)
    fpr = 1 - TN/(TN+FP)

    return tpr, fpr

# %%
def get_all_roc_coordinates(y_real, y_proba):

    tpr_list = [0]
    fpr_list = [0]
    for i in range(len(y_proba)):
        threshold = y_proba[i]
        y_pred = y_proba >= threshold
        tpr, fpr = calculate_tpr_fpr(y_real, y_pred)
        tpr_list.append(tpr)
        fpr_list.append(fpr)
    return tpr_list, fpr_list

# %%
def plot_roc_curve(tpr, fpr, scatter = True, ax = None):

    if ax == None:
        plt.figure(figsize = (5, 5))
        ax = plt.axes()

    if scatter:
        sns.scatterplot(x = fpr, y = tpr, ax = ax)
    sns.lineplot(x = fpr, y = tpr, ax = ax)
    sns.lineplot(x = [0, 1], y = [0, 1], color = 'green', ax = ax)
    plt.xlim(-0.05, 1.05)
    plt.ylim(-0.05, 1.05)
    plt.xlabel("False Positive Rate")
    plt.ylabel("True Positive Rate")

# %%
classes = gnb.classes_
classes
# Out:
# array([0, 1, 2, 3])

# %%
from sklearn.metrics import roc_auc_score

# Prediksi probabilitas untuk data uji
gnb_proba = gnb.predict_proba(x_test)

# Plots the Probability Distributions and the ROC Curves One vs Rest
plt.figure(figsize=(12, 8))
bins = [i/20 for i in range(20)] + [1]
roc_auc_ovr_gnb = {}
quality_names = ['buruk', 'baik', 'sangat_baik']

# Determine unique classes
classes = y_test['quality'].unique()

for i in range(len(quality_names)):  # Gunakan len(quality_names) untuk membatasi iterasi sejumlah elemen dalam quality_names
    # Pastikan indeks i tidak melampaui jumlah kelas yang unik
    if i < len(classes):
        # Gets the class
        c = classes[i]

        # Prepares an auxiliary dataframe to help with the plots
        df_aux = pd.DataFrame(x_test).copy()
        df_aux['quality'] = [1 if y == c else 0 for y in y_test['quality']]
        df_aux['prob'] = gnb_proba[:, i]
        df_aux = df_aux.reset_index(drop=True)

        # Plots the probability distribution for the PriceCategory and the rest
        ax = plt.subplot(2, 3, i+1)
        sns.histplot(x="prob", data=df_aux, hue='quality', color='b', ax=ax, bins=bins)
        ax.set_title(quality_names[i])
        ax.legend([f"quality: {quality_names[i]}", f"Non-{quality_names[i]}"])
        ax.set_xlabel(f"P(x = {quality_names[i]})")

        # Calculates the ROC Coordinates and plots the ROC Curves
        ax_bottom = plt.subplot(2, 3, i+4)
        tpr, fpr = get_all_roc_coordinates(df_aux['quality'], df_aux['prob'])
        plot_roc_curve(tpr, fpr, scatter=False, ax=ax_bottom)
        ax_bottom.set_title("ROC Curve OvR")

        # Calculates the ROC AUC OvR
        roc_auc_ovr_gnb[c] = roc_auc_score(df_aux['quality'], df_aux['prob'])

# Menampilkan plot
plt.suptitle('Probability Distributions and ROC Curves for Gaussian Naive Bayes')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning:
#
# X has feature names, but GaussianNB was fitted without feature names

# %% [markdown]
# Berdasarkan gambar, model NB berkinerja cukup baik dalam mengklasifikasikan contoh data untuk semua kategori. Model NB untuk kategori baik memiliki akurasi tertinggi (88,89%), diikuti oleh model NB untuk kategori sangat_baik (87,50%) dan model NB untuk kategori buruk (85,71%).

# %%
classes = knn.classes_
classes
# Out:
# array([0, 1, 2, 3])

# %%
from sklearn.metrics import roc_auc_score

# Prediksi probabilitas untuk data uji
knn_proba = knn.predict_proba(x_test)

# Plots the Probability Distributions and the ROC Curves One vs Rest
plt.figure(figsize=(12, 8))
bins = [i/20 for i in range(20)] + [1]
roc_auc_ovr_knn = {}
quality_names = ['buruk', 'baik', 'sangat_baik']  # Mengubah PriceCategory_names menjadi quality_names

for i in range(len(quality_names)):
    # Gets the class
    c = classes[i]

    # Prepares an auxiliary dataframe to help with the plots
    df_aux = pd.DataFrame(x_test_norm).copy()
    df_aux['quality'] = [1 if y == c else 0 for y in y_test['quality']]  # Mengubah PriceCategory menjadi quality
    df_aux['prob'] = knn_proba[:, i]
    df_aux = df_aux.reset_index(drop=True)

    # Plots the probability distribution for the class and the rest
    ax = plt.subplot(2, 3, i+1)
    sns.histplot(x="prob", data=df_aux, hue='quality', color='b', ax=ax, bins=bins)
    ax.set_title(quality_names[i])
    ax.legend([f"quality: {quality_names[i]}", f"Non-{quality_names[i]}"])
    ax.set_xlabel(f"P(x = {quality_names[i]})")

    # Calculates the ROC Coordinates and plots the ROC Curves
    ax_bottom = plt.subplot(2, 3, i+4)
    tpr, fpr = get_all_roc_coordinates(df_aux['quality'], df_aux['prob'])
    plot_roc_curve(tpr, fpr, scatter=False, ax=ax_bottom)
    ax_bottom.set_title("ROC Curve OvR")

    # Calculates the ROC AUC OvR
    roc_auc_ovr_knn[c] = roc_auc_score(df_aux['quality'], df_aux['prob'])

plt.suptitle('Probability Distributions and ROC Curves for K-Nearest Neighbor')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning:
#
# X has feature names, but KNeighborsClassifier was fitted without feature names

# %% [markdown]
# Model NB untuk kategori buruk memiliki akurasi tertinggi (93,75%), diikuti oleh model NB untuk kategori sangat_baik (95,65%). Model NB untuk kategori baik memiliki akurasi yang lebih rendah (82,87%) dibandingkan dengan dua kategori lainnya.

# %%
classes = dtc.classes_
classes
# Out:
# array([0, 1, 2, 3])

# %%
from sklearn.metrics import roc_auc_score

# Prediksi probabilitas untuk data uji
dtc_proba = dtc.predict_proba(x_test)

# Plots the Probability Distributions and the ROC Curves One vs Rest
plt.figure(figsize=(12, 8))
bins = [i/20 for i in range(20)] + [1]
roc_auc_ovr_dtc = {}
quality_names = ['buruk', 'baik', 'sangat_baik']  # Mengubah PriceCategory_names menjadi quality_names

for i in range(len(quality_names)):
    # Gets the class
    c = classes[i]

    # Prepares an auxiliary dataframe to help with the plots
    df_aux = pd.DataFrame(x_test_norm).copy()
    df_aux['quality'] = [1 if y == c else 0 for y in y_test['quality']]  # Mengubah PriceCategory menjadi quality
    df_aux['prob'] = dtc_proba[:, i]
    df_aux = df_aux.reset_index(drop=True)

    # Plots the probability distribution for the class and the rest
    ax = plt.subplot(2, 3, i+1)
    sns.histplot(x="prob", data=df_aux, hue='quality', color='b', ax=ax, bins=bins)
    ax.set_title(quality_names[i])
    ax.legend([f"quality: {quality_names[i]}", f"Non-{quality_names[i]}"])
    ax.set_xlabel(f"P(x = {quality_names[i]})")

    # Calculates the ROC Coordinates and plots the ROC Curves
    ax_bottom = plt.subplot(2, 3, i+4)
    tpr, fpr = get_all_roc_coordinates(df_aux['quality'], df_aux['prob'])
    plot_roc_curve(tpr, fpr, scatter=False, ax=ax_bottom)
    ax_bottom.set_title("ROC Curve OvR")

    # Calculates the ROC AUC OvR
    roc_auc_ovr_dtc[c] = roc_auc_score(df_aux['quality'], df_aux['prob'])

plt.suptitle('Probability Distributions and ROC Curves for Decision Tree')
plt.tight_layout()
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:432: UserWarning:
#
# X has feature names, but DecisionTreeClassifier was fitted without feature names

# %% [markdown]
# Model NB untuk kategori baik memiliki akurasi tertinggi (88,89%), diikuti oleh model NB untuk kategori sangat_baik (87,50%) dan model NB untuk kategori buruk (85,71%).

# %% [markdown]
# # Review Proses

# %% [markdown]
# ## Cross Validation

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import cross_val_score

# Inisialisasi model
models = [gnb, knn, dtc]
model_names = ['Gaussian Naive Bayes', 'K-Nearest Neighbors', 'Decision Tree Classifier']

# Lakukan validasi silang untuk setiap model
cv_scores = []
for model in models:
    scores = cross_val_score(model, x_train_norm, y_train, cv=5)
    cv_scores.append(scores)

# Buat dataframe dari hasil validasi silang
df_cv_scores = pd.DataFrame(cv_scores, index=model_names).T

# Tampilkan visualisasi hasil validasi silang dengan lineplot
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_cv_scores, markers=True)
plt.title('Cross-Validation Scores for Different Models')
plt.xlabel('Fold')
plt.ylabel('Accuracy')
plt.grid(True)
plt.legend(title='Model', loc='lower right')
plt.xticks(ticks=range(5), labels=['Fold 1', 'Fold 2', 'Fold 3', 'Fold 4', 'Fold 5'])
plt.show()

# %% [markdown]
# Dalam visualisasi tersebut, setiap garis mewakili akurasi dari setiap lipatan dalam validasi silang. Garis Decision Tree memiliki akurasi yang konsisten tinggi di setiap lipatan, diikuti oleh KNN yang memiliki variasi sedikit lebih besar dalam akurasi. Naive Bayes menunjukkan akurasi yang lebih rendah secara konsisten di setiap lipatan. Dengan demikian, urutan performa terbaik adalah:
#
# 1. Gaussian Naive Bayes (GNB)
# 2. K-Nearest Neighbors
# 3. Decision Tree Clasifier

# %% [markdown]
# ## Featur Selection

# %%
x_train = x_train.iloc[:, [0, 1, 2, 3, 4, 5]]

# %%
x_train_norm = x_train_norm[:, [0, 1, 2, 3, 4, 5]]

# %%
from sklearn.feature_selection import SelectKBest, chi2
import matplotlib.pyplot as plt

# Pilih fitur terbaik dengan SelectKBest
selector = SelectKBest(score_func=chi2, k=5)
selector.fit(x_train_norm, y_train)

# Ambil indeks fitur terbaik
selected_feature_indices = selector.get_support(indices=True)

# Ambil nama fitur yang terpilih
selected_feature_names = x_train.columns[selected_feature_indices]

# Filter data training dan testing hanya untuk fitur-fitur terpilih
x_train_selected = x_train[selected_feature_names]
x_test_selected = x_test[selected_feature_names]

# Plot ranking fitur
feature_ranks = selector.scores_
feature_ranks_df = pd.DataFrame({'Feature': x_train.columns, 'Rank': feature_ranks})
feature_ranks_df = feature_ranks_df.sort_values(by='Rank', ascending=False)

plt.figure(figsize=(10, 6))
plt.barh(feature_ranks_df['Feature'], feature_ranks_df['Rank'], color='skyblue')
plt.xlabel('Rank')
plt.ylabel('Feature')
plt.title('Feature Ranking')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# ini adalah diagram batang yang menunjukkan seberapa penting sebuah kolom dalam pelatihan pemodelan, dikarenakan dataset saya ada banyak kolom nya maka saya hanya akan melihatkan 6 kolom terpenting untuk latihan model. Bisa dilihat kolom terpenting untuk pelatihan permodelan yaitu citric acid.

# %% [markdown]
# ## Tuning Hypermeter

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.naive_bayes import GaussianNB

# Definisikan ruang parameter
param_grid = {
    'var_smoothing': np.logspace(0, -9, num=100)
}

# Inisialisasi GridSearchCV dengan model Gaussian Naive Bayes
grid_search = GridSearchCV(estimator=GaussianNB(), param_grid=param_grid, cv=5)

# Melakukan penelusuran grid untuk mencari parameter terbaik
grid_search.fit(x_train_selected, y_train)

# Menampilkan parameter terbaik yang ditemukan
print("Parameter terbaik:", grid_search.best_params_)

# Menggunakan model sebelum tuning untuk menghitung akurasi
gnb_before_tuning = GaussianNB().fit(x_train_selected, y_train)
acc_before_tuning = gnb_before_tuning.score(x_test_selected, y_test)
print("Akurasi sebelum tuning:", acc_before_tuning)

# Menggunakan model terbaik yang ditemukan dari GridSearchCV
best_gnb = grid_search.best_estimator_

# Menggunakan model terbaik untuk menghitung akurasi setelah tuning
acc_after_tuning = best_gnb.score(x_test_selected, y_test)
print("Akurasi setelah tuning:", acc_after_tuning)
# Out:
# Parameter terbaik: {'var_smoothing': 2.848035868435799e-07}
# Akurasi sebelum tuning: 0.46075085324232085
# Akurasi setelah tuning: 0.4641638225255973

# %% [markdown]
# Akurasi Sebelum Tuning: 0.46075085324232085
# Ini adalah akurasi model sebelum tuning, yang diperoleh dari model Gaussian Naive Bayes dengan parameter default sebelum dilakukan tuning. Akurasi ini menunjukkan kinerja model sebelum ditingkatkan melalui proses tuning.
#
# Akurasi Setelah Tuning: 0.4641638225255973
# Ini adalah akurasi model setelah tuning, yang diperoleh dari model Gaussian Naive Bayes dengan parameter terbaik yang ditemukan oleh GridSearchCV. Akurasi ini menunjukkan kinerja model setelah parameter diatur ulang untuk meningkatkan kinerja berdasarkan data validasi yang digunakan dalam proses tuning.

# %%
gnb = GaussianNB(var_smoothing=2.848035868435799)

# %% [markdown]
# # Determine Next Step

# %% [markdown]
# Untuk menentukan algoritma yang optimal setelah melakukan evaluasi model klasifikasi, Anda dapat mempertimbangkan beberapa faktor, termasuk akurasi, presisi, recall, dan F1-score. Berdasarkan hasil yang Anda berikan, kami memiliki metrik evaluasi untuk tiga algoritma klasifikasi: Gaussian Naive Bayes, K Nearest Neighbor, dan Decision Tree Classifier.
#
# 1. **Gaussian Naive Bayes**:
#    - Akurasi: 0.5631399317406144
#    - Presisi: 0.44900524312289014
#    - Recall: 0.4976610012163114
#    - F1-score: 0.4617149089832318
#
# 2. **K Nearest Neighbor (KNN)**:
#    - Akurasi: 0.6075085324232082
#    - Presisi: 0.4427301555415255
#    - Recall: 0.43338637548355236
#    - F1-score: 0.43632502667935746
#
# 3. **Decision Tree Classifier**:
#    - Akurasi: 0.5051194539249146
#    - Presisi: 0.4125383736703077
#    - Recall: 0.4576777369292253
#    - F1-score: 0.4280046636284062
#
# Berdasarkan hasil evaluasi tersebut, kita dapat mengambil beberapa kesimpulan:
#
# - **Akurasi Tertinggi**: KNN memiliki akurasi tertinggi (0.6075), diikuti oleh Gaussian Naive Bayes (0.5631) dan Decision Tree Classifier (0.5051).
#
# - **Presisi Tertinggi**: Gaussian Naive Bayes memiliki presisi tertinggi (0.449), diikuti oleh KNN (0.443) dan Decision Tree Classifier (0.413).
#
# - **Recall Tertinggi**: Decision Tree Classifier memiliki recall tertinggi (0.458), diikuti oleh Gaussian Naive Bayes (0.498) dan KNN (0.433).
#
# - **F1-score Tertinggi**: KNN memiliki F1-score tertinggi (0.436), diikuti oleh Gaussian Naive Bayes (0.462) dan Decision Tree Classifier (0.428).
#
# Berdasarkan evaluasi ini, KNN mungkin merupakan pilihan yang optimal karena memiliki akurasi yang baik serta nilai presisi, recall, dan F1-score yang seimbang. Namun, keputusan akhir tergantung pada preferensi Anda dan kebutuhan spesifik dari masalah klasifikasi yang Anda hadapi. Selain itu, perlu juga mempertimbangkan faktor lain seperti biaya komputasi, interpretabilitas model, dan karakteristik data.
